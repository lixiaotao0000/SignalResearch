# %% [markdown]
# ## 策略逻辑：
# 60分钟看长短期MA趋势， 15分钟做均线择时。

# %%
from __future__ import division
from vnpy.trader.vtConstant import *
from vnpy.trader.app.ctaStrategy import CtaTemplate
import talib as ta

########################################################################
# 策略继承CtaTemplate
class MultiFrameMaStrategy(CtaTemplate):
    className = 'MultiFrameMaStrategy'
    author = 'ChannelCMT'
    
    # 策略参数
    fastPeriod = 33; slowPeriod = 55
    signalMaPeriod = 20
    lot = 1
    
    # 策略变量
    maTrend = {} # 记录趋势状态，多头1，空头-1
    transactionPrice = {} # 记录成交价格
    
    # 参数列表，保存了参数的名称
    paramList = [
                 'fastPeriod', 'slowPeriod',
                 'signalMaPeriod'
                ]    
    
    # 变量列表，保存了变量的名称
    varList = [
               'maTrend',
               'transactionPrice'
              ]  
    
    # 同步列表，保存了需要保存到数据库的变量名称
    syncList = ['posDict', 'eveningDict']

    #----------------------------------------------------------------------
    def __init__(self, ctaEngine, setting):
        super().__init__(ctaEngine, setting)
    
    #----------------------------------------------------------------------
    def onInit(self):
        """初始化策略"""
        self.writeCtaLog(u'策略初始化')
        self.transactionPrice = {s:0 for s in self.symbolList} # 生成成交价格的字典
        self.maTrend = {s:0 for s in self.symbolList}
        self.putEvent()

    #----------------------------------------------------------------------
    def onStart(self):
        """启动策略"""
        self.writeCtaLog(u'策略启动')
        self.putEvent()
    
    #----------------------------------------------------------------------
    def onStop(self):
        """停止策略"""
        self.writeCtaLog(u'策略停止')
        self.putEvent()
        
    #----------------------------------------------------------------------
    def onTick(self, tick):
        """收到行情TICK推送"""
        pass
    
    #----------------------------------------------------------------------
    def onBar(self, bar):
        """收到Bar推送"""
        pass
    
    #----------------------------------------------------------------------
    def on60MinBar(self, bar):
        """收到60MinBar推送"""
        symbol = bar.vtSymbol
        
        am60 = self.getArrayManager(symbol, "60m")
        
        if not am60.inited:
            return
        
        # 计算均线并判断趋势
        fastMa = ta.MA(am60.close, self.fastPeriod)
        slowMa = ta.MA(am60.close, self.slowPeriod)
        
        if fastMa[-1] > slowMa[-1]:
            self.maTrend[symbol] = 1
        else:
            self.maTrend[symbol] = -1
    
    #----------------------------------------------------------------------
    def on15MinBar(self, bar):
        """收到15MinBar推送"""
        symbol = bar.vtSymbol
        
        am15 = self.getArrayManager(symbol, "15m")
        
        if not am15.inited:
            return

        signalMa = ta.EMA(am15.close, self.signalMaPeriod)

        maUp = signalMa[-1]>signalMa[-3] # 均线上涨
        maDn = signalMa[-1]<signalMa[-3] # 均线下跌
        
        # 均线上涨， 趋势为多头， 多头没有持仓
        if maUp and (self.maTrend[symbol]==1) and (self.posDict[symbol+'_LONG']==0):
            if  (self.posDict[symbol+'_SHORT']==0):
                self.buy(symbol, bar.close*1.01, self.lot)  # 成交价*1.01发送高价位的限价单，以最优市价买入进场
            elif (self.posDict[symbol+'_SHORT'] > 0):
                self.cancelAll() # 撤销挂单
                self.cover(symbol, bar.close*1.01, self.posDict[symbol+'_SHORT']) 
                self.buy(symbol, bar.close*1.01, self.lot)
        
        # 均线下跌， 趋势为空头， 空头没有持仓
        if maDn and (self.maTrend[symbol]==-1) and (self.posDict[symbol+'_SHORT']==0):
            if (self.posDict[symbol+'_LONG']==0):
#                 self.cancelAll() # 撤销挂单
                self.short(symbol, bar.close*0.99, self.lot) # 成交价*0.99发送低价位的限价单，以最优市价卖出进场
            elif (self.posDict[symbol+'_LONG'] > 0):
                self.cancelAll() # 撤销挂单
                self.sell(symbol, bar.close*0.99, self.posDict[symbol+'_LONG'])
                self.short(symbol, bar.close*0.99, self.lot)
        self.putEvent()
    
    #----------------------------------------------------------------------
    def onOrder(self, order):
        """收到委托变化推送（必须由用户继承实现）"""
        # 对于无需做细粒度委托控制的策略，可以忽略onOrder
        pass
    
    #----------------------------------------------------------------------
    def onTrade(self, trade):
        """收到成交推送（必须由用户继承实现）"""
        # 对于无需做交易信息记录的策略，可以忽略onTrade
        pass
    #----------------------------------------------------------------------
    def onStopOrder(self, so):
        """停止单推送"""
        pass

# %% [markdown]
# ## 配置引擎回测

# %%
if __name__=="__main__":
    from vnpy.trader.app.ctaStrategy import BacktestingEngine

    # 创建回测引擎对象
    engine = BacktestingEngine()

    # 设置回测使用的数据
    engine.setBacktestingMode(engine.BAR_MODE)    # 设置引擎的回测模式为K线
    engine.setDatabase('VnTrader_1Min_Db')  # 设置使用的历史数据库
    engine.setStartDate('20180901 12:00',initHours=200) # 设置回测用的数据起始日期
    engine.setEndDate('20181123 12:00') # 设置回测用的数据终止日期

    # 配置回测引擎参数
    engine.setSlippage(0.002)    # 设置滑点
    engine.setRate(5/10000)   # 设置手续费千1
    engine.setCapital(1000000)  # 设置回测本金

    # # 在引擎中创建策略对象
    parameterDict = {'symbolList':['BTCUSDT:binance']}          # 策略参数配置
    engine.initStrategy(MultiFrameMaStrategy, parameterDict)    # 创建策略对象
    engine.runBacktesting()
# Out:
# 仓位字典构造完成
# 初始仓位: {'BTCUSDT:binance_LONG': 0, 'BTCUSDT:binance_SHORT': 0}
# [DEBUG] 注册品种BTCUSDT:binance上的on_60Min_bar函数functools.partial(<function MultiFrameMaStrategy.on60MinBar at 0x0000023444A56598>, <__main__.MultiFrameMaStrategy object at 0x0000023446D2FB70>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_15Min_bar函数functools.partial(<function MultiFrameMaStrategy.on15MinBar at 0x0000023444A560D0>, <__main__.MultiFrameMaStrategy object at 0x0000023446D2FB70>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_1m_bar函数functools.partial(<function MultiFrameMaStrategy.onBar at 0x0000023444A566A8>, <__main__.MultiFrameMaStrategy object at 0x0000023446D2FB70>)
# 2018-12-17 22:32:21.412828	开始回测
# 2018-12-17 22:32:21.412828	策略初始化
# 2018-12-17 22:32:21.414823	载入历史数据。数据范围:[20180824 04:00,20180901 12:00)
# 2018-12-17 22:32:22.033169	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 22:32:22.035163	载入完成，数据量：12000
# 2018-12-17 22:32:22.035163	策略初始化完成
# 2018-12-17 22:32:22.035163	策略启动完成
# 2018-12-17 22:32:22.035163	开始回放回测数据,回测范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 22:32:22.044139	载入历史数据。数据范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 22:32:27.815319	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 22:32:27.841284	载入完成，数据量：118890
# 2018-12-17 22:32:27.841284	当前回放数据:[20180901 12:00,20181123 12:00)
# [INFO] 品种BTCUSDT:binance开始生成未完成的1mK线数据,时间起点为:20180901120000
# 2018-12-17 22:32:27.843246	载入历史数据。数据范围:[20180831 20:51,20180903 12:01)
# 2018-12-17 22:32:28.030177	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 22:32:28.030177	载入完成，数据量：3790
# [INFO] 品种BTCUSDT:binance的历史1mK线更新，范围为:[20180901102100 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的1mK线准备就绪,当前K线时间为20180901120000
# [INFO] 品种BTCUSDT:binance开始生成未完成的60mK线数据,时间起点为:20180901120000
# 2018-12-17 22:32:28.053144	载入历史数据。数据范围:[20180725 15:00,20180831 20:50)
# 2018-12-17 22:32:30.319225	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 22:32:30.330229	载入完成，数据量：53630
# 2018-12-17 22:32:30.336178	载入历史数据。数据范围:[20180903 12:01,20180903 13:00)
# 2018-12-17 22:32:30.341166	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 22:32:30.341166	！！ 数据量为 0 ！！
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828080000 , 20180901110000]
# [INFO] 品种BTCUSDT:binance开始生成未完成的15mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831110000 , 20180901114500]
# [INFO] 品种BTCUSDT:binance开始生成1mK线数据,时间起点为:20180901120100
# [INFO] 品种BTCUSDT:binance开始生成60mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance开始生成15mK线数据,时间起点为:20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7054.86, 'close': 7059.99, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 381.507684, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831111500 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的15mK线准备就绪,当前K线时间为20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7039.8, 'close': 7054.02, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 1380.226004, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828090000 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的60mK线准备就绪,当前K线时间为20180901120000
# 2018-12-17 22:32:39.871551	数据回放结束ss: 100%

# %%
import pandas as pd
tradeReport = pd.DataFrame([obj.__dict__ for obj in engine.tradeDict.values()])
tradeDf = tradeReport.set_index('dt')
tradeDf.tail()
# Out:
#                     direction exchange exchangeOrderID  fee gatewayName  \
# dt
# 2018-11-19 18:00:00         空                           0.0
# 2018-11-22 23:00:00         多                           0.0
# 2018-11-22 23:00:00         多                           0.0
# 2018-11-23 00:15:00         空                           0.0
# 2018-11-23 00:15:00         空                           0.0
#
#                     offset orderID orderTime    price  price_avg rawData  \
# dt
# 2018-11-19 18:00:00     开仓      75            5275.14        0.0    None
# 2018-11-22 23:00:00     平仓      76            4559.01        0.0    None
# 2018-11-22 23:00:00     开仓      77            4559.01        0.0    None
# 2018-11-23 00:15:00     平仓      78            4546.41        0.0    None
# 2018-11-23 00:15:00     开仓      79            4546.41        0.0    None
#
#                     status symbol tradeID           tradeTime  volume  \
# dt
# 2018-11-19 18:00:00                    75 2018-11-19 18:00:00       1
# 2018-11-22 23:00:00                    76 2018-11-22 23:00:00       1
# 2018-11-22 23:00:00                    77 2018-11-22 23:00:00       1
# 2018-11-23 00:15:00                    78 2018-11-23 00:15:00       1
# 2018-11-23 00:15:00                    79 2018-11-23 00:15:00       1
#
#                     vtOrderID         vtSymbol vtTradeID
# dt
# 2018-11-19 18:00:00        75  BTCUSDT:binance        75
# 2018-11-22 23:00:00        76  BTCUSDT:binance        76
# 2018-11-22 23:00:00        77  BTCUSDT:binance        77
# 2018-11-23 00:15:00        78  BTCUSDT:binance        78
# 2018-11-23 00:15:00        79  BTCUSDT:binance        79

# %% [markdown]
# ## 查看绩效与优化

# %%
# 显示逐日回测结果
engine.showDailyResult()
# Out:
# 2018-12-17 22:32:39.917428	计算按日统计结果
# 2018-12-17 22:32:39.956332	------------------------------
# 2018-12-17 22:32:39.957322	首个交易日：	2018-09-01 00:00:00
# 2018-12-17 22:32:39.957322	最后交易日：	2018-11-23 00:00:00
# 2018-12-17 22:32:39.957322	总交易日：	84
# 2018-12-17 22:32:39.957322	盈利交易日	51
# 2018-12-17 22:32:39.957322	亏损交易日：	32
# 2018-12-17 22:32:39.957322	起始资金：	1000000
# 2018-12-17 22:32:39.957322	结束资金：	1,002,899.12
# 2018-12-17 22:32:39.957322	总收益率：	0.29%
# 2018-12-17 22:32:39.958334	年化收益：	0.83%
# 2018-12-17 22:32:39.959317	总盈亏：	2,899.12
# 2018-12-17 22:32:39.959317	最大回撤: 	-472.58
# 2018-12-17 22:32:39.960317	百分比最大回撤: -0.05%
# 2018-12-17 22:32:39.960317	总手续费：	251.85
# 2018-12-17 22:32:39.960317	总滑点：	0.16
# 2018-12-17 22:32:39.960317	总成交金额：	503,695.68
# 2018-12-17 22:32:39.960317	总成交笔数：	79
# 2018-12-17 22:32:39.960317	日均盈亏：	34.51
# 2018-12-17 22:32:39.960317	日均手续费：	3.0
# 2018-12-17 22:32:39.960317	日均滑点：	0.0
# 2018-12-17 22:32:39.960317	日均成交金额：	5,996.38
# 2018-12-17 22:32:39.960317	日均成交笔数：	0.94
# 2018-12-17 22:32:39.960317	日均收益率：	0.0%
# 2018-12-17 22:32:39.961311	收益标准差：	0.01%
# 2018-12-17 22:32:39.961311	Sharpe Ratio：	3.63

# %%
# 显示逐笔回测结果
engine.showBacktestingResult()
# Out:
# 2018-12-17 22:34:06.738330	计算回测结果
# 2018-12-17 22:34:06.742319	------------------------------
# 2018-12-17 22:34:06.742319	第一笔交易：	2018-09-06 01:00:00
# 2018-12-17 22:34:06.742319	最后一笔交易：	2018-11-23 11:58:00
# 2018-12-17 22:34:06.742319	总交易次数：	40
# 2018-12-17 22:34:06.742319	总盈亏：	2,896.96
# 2018-12-17 22:34:06.742319	最大回撤: 	-372.7
# 2018-12-17 22:34:06.743316	平均每笔盈利：	72.42
# 2018-12-17 22:34:06.743316	平均每笔滑点：	0.0
# 2018-12-17 22:34:06.743316	平均每笔佣金：	6.35
# 2018-12-17 22:34:06.743316	胜率		47.5%
# 2018-12-17 22:34:06.743316	盈利交易平均值	227.3
# 2018-12-17 22:34:06.743316	亏损交易平均值	-67.7
# 2018-12-17 22:34:06.743316	盈亏比：	3.36

# %%
df = engine.calculateDailyResult()
df1, result = engine.calculateDailyStatistics(df)
print(pd.Series(result))
# Out:
# 2018-12-17 21:03:39.104464	计算按日统计结果
# startDate           2018-09-01 00:00:00
# endDate             2018-11-23 00:00:00
# totalDays                            84
# profitDays                           54
# lossDays                             29
# endBalance                  1.00334e+06
# maxDrawdown                    -308.747
# maxDdPercent                 -0.0308648
# totalNetPnl                     3343.23
# dailyNetPnl                     39.8003
# totalCommission                 230.162
# dailyCommission                 2.74002
# totalSlippage                     0.142
# dailySlippage                0.00169048
# totalTurnover                    460323
# dailyTurnover                   5480.04
# totalTradeCount                      71
# dailyTradeCount                0.845238
# totalReturn                    0.334323
# annualizedReturn               0.955208
# dailyReturn                  0.00384366
# returnStd                     0.0140566
# sharpeRatio                     4.23614
# dtype: object

# %%
from vnpy.trader.app.ctaStrategy.ctaBacktesting  import OptimizationSetting
# 优化配置
setting = OptimizationSetting()                # 新建一个优化任务设置对象
setting.setOptimizeTarget('sharpeRatio')        # 设置优化排序的目标是夏普
setting.addParameter('fastPeriod', 15, 35, 3)    # 增加第一个优化参数，起始30，结束50，步进10
setting.addParameter('slowPeriod', 40, 100, 5)    # 增加第二个优化参数，起始60，结束30，步进10
# setting.addParameter('signalMaPeriod', 10, 20, 5)    # 增加第二个优化参数，起始10，结束30，步进5

setting.addParameter('symbolList', ['BTCUSDT:binance']) 

import time
start = time.time()
# 执行单线程优化
resultList = engine.runOptimization(MultiFrameMaStrategy, setting)
# 执行多进程优化一般会改写成py文件然后用多线程运行，提高优化速度。
# resultList = engine.runParallelOptimization(MultiFrameMaStrategy, setting)
print('耗时：%s' %(time.time()-start))
# Out:
# 2018-12-17 21:55:08.691238	------------------------------
# 2018-12-17 21:55:08.691238	setting: {'fastPeriod': 15, 'slowPeriod': 40, 'symbolList': ['BTCUSDT:binance']}
# 仓位字典构造完成
# 初始仓位: {'BTCUSDT:binance_LONG': 0, 'BTCUSDT:binance_SHORT': 0}
# [DEBUG] 注册品种BTCUSDT:binance上的on_60Min_bar函数functools.partial(<function MultiFrameMaStrategy.on60MinBar at 0x000002344EB0D158>, <__main__.MultiFrameMaStrategy object at 0x0000023449BE3F60>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_15Min_bar函数functools.partial(<function MultiFrameMaStrategy.on15MinBar at 0x000002344EB0D0D0>, <__main__.MultiFrameMaStrategy object at 0x0000023449BE3F60>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_1m_bar函数functools.partial(<function MultiFrameMaStrategy.onBar at 0x000002344EB0DBF8>, <__main__.MultiFrameMaStrategy object at 0x0000023449BE3F60>)
# 2018-12-17 21:55:08.724147	开始回测
# 2018-12-17 21:55:08.724147	策略初始化
# 2018-12-17 21:55:08.725171	载入历史数据。数据范围:[20180824 04:00,20180901 12:00)
# 2018-12-17 21:55:09.273832	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:55:09.276789	载入完成，数据量：12000
# 2018-12-17 21:55:09.276789	策略初始化完成
# 2018-12-17 21:55:09.276789	策略启动完成
# 2018-12-17 21:55:09.276789	开始回放回测数据,回测范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:55:09.284797	载入历史数据。数据范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:55:14.671547	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:55:14.696481	载入完成，数据量：118890
# 2018-12-17 21:55:14.696481	当前回放数据:[20180901 12:00,20181123 12:00)
# [INFO] 品种BTCUSDT:binance开始生成未完成的1mK线数据,时间起点为:20180901120000
# 2018-12-17 21:55:14.697475	载入历史数据。数据范围:[20180831 20:51,20180903 12:01)
# 2018-12-17 21:55:14.916452	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:55:14.917450	载入完成，数据量：3790
# [INFO] 品种BTCUSDT:binance的历史1mK线更新，范围为:[20180901102100 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的1mK线准备就绪,当前K线时间为20180901120000
# [INFO] 品种BTCUSDT:binance开始生成未完成的60mK线数据,时间起点为:20180901120000
# 2018-12-17 21:55:14.936400	载入历史数据。数据范围:[20180725 15:00,20180831 20:50)
# 2018-12-17 21:55:17.574602	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:55:17.585576	载入完成，数据量：53630
# 2018-12-17 21:55:17.590561	载入历史数据。数据范围:[20180903 12:01,20180903 13:00)
# 2018-12-17 21:55:17.605522	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:55:17.605522	！！ 数据量为 0 ！！
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828080000 , 20180901110000]
# [INFO] 品种BTCUSDT:binance开始生成未完成的15mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831110000 , 20180901114500]
# [INFO] 品种BTCUSDT:binance开始生成1mK线数据,时间起点为:20180901120100
# [INFO] 品种BTCUSDT:binance开始生成60mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance开始生成15mK线数据,时间起点为:20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7054.86, 'close': 7059.99, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 381.507684, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831111500 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的15mK线准备就绪,当前K线时间为20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7039.8, 'close': 7054.02, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 1380.226004, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828090000 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的60mK线准备就绪,当前K线时间为20180901120000
# 2018-12-17 21:55:26.504332	数据回放结束ss: 100%
# 2018-12-17 21:55:26.504332	计算按日统计结果
# 2018-12-17 21:55:26.564171	------------------------------
# 2018-12-17 21:55:26.565170	setting: {'fastPeriod': 15, 'slowPeriod': 45, 'symbolList': ['BTCUSDT:binance']}
# 仓位字典构造完成
# 初始仓位: {'BTCUSDT:binance_LONG': 0, 'BTCUSDT:binance_SHORT': 0}
# [DEBUG] 注册品种BTCUSDT:binance上的on_60Min_bar函数functools.partial(<function MultiFrameMaStrategy.on60MinBar at 0x000002344EB0DEA0>, <__main__.MultiFrameMaStrategy object at 0x000002344CF6FF98>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_15Min_bar函数functools.partial(<function MultiFrameMaStrategy.on15MinBar at 0x000002344EB0D158>, <__main__.MultiFrameMaStrategy object at 0x000002344CF6FF98>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_1m_bar函数functools.partial(<function MultiFrameMaStrategy.onBar at 0x000002344EB0D0D0>, <__main__.MultiFrameMaStrategy object at 0x000002344CF6FF98>)
# 2018-12-17 21:55:26.598081	开始回测
# 2018-12-17 21:55:26.598081	策略初始化
# 2018-12-17 21:55:26.599079	载入历史数据。数据范围:[20180824 04:00,20180901 12:00)
# 2018-12-17 21:55:27.111683	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:55:27.114678	载入完成，数据量：12000
# 2018-12-17 21:55:27.114678	策略初始化完成
# 2018-12-17 21:55:27.114678	策略启动完成
# 2018-12-17 21:55:27.114678	开始回放回测数据,回测范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:55:27.122656	载入历史数据。数据范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:55:32.564088	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:55:32.588024	载入完成，数据量：118890
# 2018-12-17 21:55:32.588024	当前回放数据:[20180901 12:00,20181123 12:00)
# [INFO] 品种BTCUSDT:binance开始生成未完成的1mK线数据,时间起点为:20180901120000
# 2018-12-17 21:55:32.589021	载入历史数据。数据范围:[20180831 20:51,20180903 12:01)
# 2018-12-17 21:55:32.774963	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:55:32.775960	载入完成，数据量：3790
# [INFO] 品种BTCUSDT:binance的历史1mK线更新，范围为:[20180901102100 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的1mK线准备就绪,当前K线时间为20180901120000
# [INFO] 品种BTCUSDT:binance开始生成未完成的60mK线数据,时间起点为:20180901120000
# 2018-12-17 21:55:32.794908	载入历史数据。数据范围:[20180725 15:00,20180831 20:50)
# 2018-12-17 21:55:35.237489	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:55:35.248493	载入完成，数据量：53630
# 2018-12-17 21:55:35.254473	载入历史数据。数据范围:[20180903 12:01,20180903 13:00)
# 2018-12-17 21:55:35.269500	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:55:35.269500	！！ 数据量为 0 ！！
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828080000 , 20180901110000]
# [INFO] 品种BTCUSDT:binance开始生成未完成的15mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831110000 , 20180901114500]
# [INFO] 品种BTCUSDT:binance开始生成1mK线数据,时间起点为:20180901120100
# [INFO] 品种BTCUSDT:binance开始生成60mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance开始生成15mK线数据,时间起点为:20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7054.86, 'close': 7059.99, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 381.507684, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831111500 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的15mK线准备就绪,当前K线时间为20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7039.8, 'close': 7054.02, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 1380.226004, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828090000 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的60mK线准备就绪,当前K线时间为20180901120000
# 2018-12-17 21:55:43.593462	数据回放结束ss: 100%
# 2018-12-17 21:55:43.593462	计算按日统计结果
# 2018-12-17 21:55:43.654268	------------------------------
# 2018-12-17 21:55:43.654268	setting: {'fastPeriod': 15, 'slowPeriod': 50, 'symbolList': ['BTCUSDT:binance']}
# 仓位字典构造完成
# 初始仓位: {'BTCUSDT:binance_LONG': 0, 'BTCUSDT:binance_SHORT': 0}
# [DEBUG] 注册品种BTCUSDT:binance上的on_60Min_bar函数functools.partial(<function MultiFrameMaStrategy.on60MinBar at 0x000002344EB0D8C8>, <__main__.MultiFrameMaStrategy object at 0x000002344DBB2F60>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_15Min_bar函数functools.partial(<function MultiFrameMaStrategy.on15MinBar at 0x000002344EB0D400>, <__main__.MultiFrameMaStrategy object at 0x000002344DBB2F60>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_1m_bar函数functools.partial(<function MultiFrameMaStrategy.onBar at 0x000002344EB0DC80>, <__main__.MultiFrameMaStrategy object at 0x000002344DBB2F60>)
# 2018-12-17 21:55:43.677207	开始回测
# 2018-12-17 21:55:43.677207	策略初始化
# 2018-12-17 21:55:43.678203	载入历史数据。数据范围:[20180824 04:00,20180901 12:00)
# 2018-12-17 21:55:44.186079	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:55:44.189101	载入完成，数据量：12000
# 2018-12-17 21:55:44.189101	策略初始化完成
# 2018-12-17 21:55:44.189101	策略启动完成
# 2018-12-17 21:55:44.189101	开始回放回测数据,回测范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:55:44.198076	载入历史数据。数据范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:55:49.297537	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:55:49.321475	载入完成，数据量：118890
# 2018-12-17 21:55:49.321475	当前回放数据:[20180901 12:00,20181123 12:00)
# [INFO] 品种BTCUSDT:binance开始生成未完成的1mK线数据,时间起点为:20180901120000
# 2018-12-17 21:55:49.322471	载入历史数据。数据范围:[20180831 20:51,20180903 12:01)
# 2018-12-17 21:55:49.500995	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:55:49.501992	载入完成，数据量：3790
# [INFO] 品种BTCUSDT:binance的历史1mK线更新，范围为:[20180901102100 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的1mK线准备就绪,当前K线时间为20180901120000
# [INFO] 品种BTCUSDT:binance开始生成未完成的60mK线数据,时间起点为:20180901120000
# 2018-12-17 21:55:49.518977	载入历史数据。数据范围:[20180725 15:00,20180831 20:50)
# 2018-12-17 21:55:51.943419	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:55:51.955387	载入完成，数据量：53630
# 2018-12-17 21:55:51.961370	载入历史数据。数据范围:[20180903 12:01,20180903 13:00)
# 2018-12-17 21:55:51.966357	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:55:51.966357	！！ 数据量为 0 ！！
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828080000 , 20180901110000]
# [INFO] 品种BTCUSDT:binance开始生成未完成的15mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831110000 , 20180901114500]
# [INFO] 品种BTCUSDT:binance开始生成1mK线数据,时间起点为:20180901120100
# [INFO] 品种BTCUSDT:binance开始生成60mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance开始生成15mK线数据,时间起点为:20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7054.86, 'close': 7059.99, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 381.507684, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831111500 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的15mK线准备就绪,当前K线时间为20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7039.8, 'close': 7054.02, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 1380.226004, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828090000 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的60mK线准备就绪,当前K线时间为20180901120000
# 2018-12-17 21:56:00.233987	数据回放结束ss: 100%
# 2018-12-17 21:56:00.233987	计算按日统计结果
# 2018-12-17 21:56:00.293931	------------------------------
# 2018-12-17 21:56:00.293931	setting: {'fastPeriod': 15, 'slowPeriod': 55, 'symbolList': ['BTCUSDT:binance']}
# 仓位字典构造完成
# 初始仓位: {'BTCUSDT:binance_LONG': 0, 'BTCUSDT:binance_SHORT': 0}
# [DEBUG] 注册品种BTCUSDT:binance上的on_60Min_bar函数functools.partial(<function MultiFrameMaStrategy.on60MinBar at 0x000002344EB0D400>, <__main__.MultiFrameMaStrategy object at 0x000002344D96AF98>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_15Min_bar函数functools.partial(<function MultiFrameMaStrategy.on15MinBar at 0x000002344EB0DC80>, <__main__.MultiFrameMaStrategy object at 0x000002344D96AF98>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_1m_bar函数functools.partial(<function MultiFrameMaStrategy.onBar at 0x000002344EB0D8C8>, <__main__.MultiFrameMaStrategy object at 0x000002344D96AF98>)
# 2018-12-17 21:56:00.316872	开始回测
# 2018-12-17 21:56:00.316872	策略初始化
# 2018-12-17 21:56:00.317871	载入历史数据。数据范围:[20180824 04:00,20180901 12:00)
# 2018-12-17 21:56:00.827844	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:56:00.830864	载入完成，数据量：12000
# 2018-12-17 21:56:00.830864	策略初始化完成
# 2018-12-17 21:56:00.830864	策略启动完成
# 2018-12-17 21:56:00.830864	开始回放回测数据,回测范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:56:00.839808	载入历史数据。数据范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:56:06.139508	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:56:06.163445	载入完成，数据量：118890
# 2018-12-17 21:56:06.164439	当前回放数据:[20180901 12:00,20181123 12:00)
# [INFO] 品种BTCUSDT:binance开始生成未完成的1mK线数据,时间起点为:20180901120000
# 2018-12-17 21:56:06.165437	载入历史数据。数据范围:[20180831 20:51,20180903 12:01)
# 2018-12-17 21:56:06.340968	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:56:06.341995	载入完成，数据量：3790
# [INFO] 品种BTCUSDT:binance的历史1mK线更新，范围为:[20180901102100 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的1mK线准备就绪,当前K线时间为20180901120000
# [INFO] 品种BTCUSDT:binance开始生成未完成的60mK线数据,时间起点为:20180901120000
# 2018-12-17 21:56:06.358919	载入历史数据。数据范围:[20180725 15:00,20180831 20:50)
# 2018-12-17 21:56:09.043741	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:56:09.056745	载入完成，数据量：53630
# 2018-12-17 21:56:09.061723	载入历史数据。数据范围:[20180903 12:01,20180903 13:00)
# 2018-12-17 21:56:09.078899	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:56:09.078899	！！ 数据量为 0 ！！
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828080000 , 20180901110000]
# [INFO] 品种BTCUSDT:binance开始生成未完成的15mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831110000 , 20180901114500]
# [INFO] 品种BTCUSDT:binance开始生成1mK线数据,时间起点为:20180901120100
# [INFO] 品种BTCUSDT:binance开始生成60mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance开始生成15mK线数据,时间起点为:20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7054.86, 'close': 7059.99, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 381.507684, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831111500 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的15mK线准备就绪,当前K线时间为20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7039.8, 'close': 7054.02, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 1380.226004, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828090000 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的60mK线准备就绪,当前K线时间为20180901120000
# 2018-12-17 21:56:19.058435	数据回放结束ss: 100%
# 2018-12-17 21:56:19.058435	计算按日统计结果
# 2018-12-17 21:56:19.158138	------------------------------
# 2018-12-17 21:56:19.158138	setting: {'fastPeriod': 15, 'slowPeriod': 60, 'symbolList': ['BTCUSDT:binance']}
# 仓位字典构造完成
# 初始仓位: {'BTCUSDT:binance_LONG': 0, 'BTCUSDT:binance_SHORT': 0}
# [DEBUG] 注册品种BTCUSDT:binance上的on_60Min_bar函数functools.partial(<function MultiFrameMaStrategy.on60MinBar at 0x000002344EB0DC80>, <__main__.MultiFrameMaStrategy object at 0x000002344D174FD0>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_15Min_bar函数functools.partial(<function MultiFrameMaStrategy.on15MinBar at 0x000002344EB0D8C8>, <__main__.MultiFrameMaStrategy object at 0x000002344D174FD0>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_1m_bar函数functools.partial(<function MultiFrameMaStrategy.onBar at 0x000002344EB0D400>, <__main__.MultiFrameMaStrategy object at 0x000002344D174FD0>)
# 2018-12-17 21:56:19.182072	开始回测
# 2018-12-17 21:56:19.182072	策略初始化
# 2018-12-17 21:56:19.183070	载入历史数据。数据范围:[20180824 04:00,20180901 12:00)
# 2018-12-17 21:56:19.808400	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:56:19.810393	载入完成，数据量：12000
# 2018-12-17 21:56:19.810393	策略初始化完成
# 2018-12-17 21:56:19.810393	策略启动完成
# 2018-12-17 21:56:19.810393	开始回放回测数据,回测范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:56:19.819394	载入历史数据。数据范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:56:25.611187	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:56:25.636149	载入完成，数据量：118890
# 2018-12-17 21:56:25.636149	当前回放数据:[20180901 12:00,20181123 12:00)
# [INFO] 品种BTCUSDT:binance开始生成未完成的1mK线数据,时间起点为:20180901120000
# 2018-12-17 21:56:25.637115	载入历史数据。数据范围:[20180831 20:51,20180903 12:01)
# 2018-12-17 21:56:25.812647	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:56:25.813679	载入完成，数据量：3790
# [INFO] 品种BTCUSDT:binance的历史1mK线更新，范围为:[20180901102100 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的1mK线准备就绪,当前K线时间为20180901120000
# [INFO] 品种BTCUSDT:binance开始生成未完成的60mK线数据,时间起点为:20180901120000
# 2018-12-17 21:56:25.832623	载入历史数据。数据范围:[20180725 15:00,20180831 20:50)
# 2018-12-17 21:56:28.336505	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:56:28.347517	载入完成，数据量：53630
# 2018-12-17 21:56:28.353487	载入历史数据。数据范围:[20180903 12:01,20180903 13:00)
# 2018-12-17 21:56:28.369445	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:56:28.370416	！！ 数据量为 0 ！！
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828080000 , 20180901110000]
# [INFO] 品种BTCUSDT:binance开始生成未完成的15mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831110000 , 20180901114500]
# [INFO] 品种BTCUSDT:binance开始生成1mK线数据,时间起点为:20180901120100
# [INFO] 品种BTCUSDT:binance开始生成60mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance开始生成15mK线数据,时间起点为:20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7054.86, 'close': 7059.99, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 381.507684, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831111500 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的15mK线准备就绪,当前K线时间为20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7039.8, 'close': 7054.02, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 1380.226004, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828090000 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的60mK线准备就绪,当前K线时间为20180901120000
# 2018-12-17 21:56:36.577576	数据回放结束ss: 100%
# 2018-12-17 21:56:36.577576	计算按日统计结果
# 2018-12-17 21:56:36.639377	------------------------------
# 2018-12-17 21:56:36.639377	setting: {'fastPeriod': 15, 'slowPeriod': 65, 'symbolList': ['BTCUSDT:binance']}
# 仓位字典构造完成
# 初始仓位: {'BTCUSDT:binance_LONG': 0, 'BTCUSDT:binance_SHORT': 0}
# [DEBUG] 注册品种BTCUSDT:binance上的on_60Min_bar函数functools.partial(<function MultiFrameMaStrategy.on60MinBar at 0x000002344EB0DF28>, <__main__.MultiFrameMaStrategy object at 0x000002344CD25FD0>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_15Min_bar函数functools.partial(<function MultiFrameMaStrategy.on15MinBar at 0x000002344EB0D730>, <__main__.MultiFrameMaStrategy object at 0x000002344CD25FD0>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_1m_bar函数functools.partial(<function MultiFrameMaStrategy.onBar at 0x000002344EB0D840>, <__main__.MultiFrameMaStrategy object at 0x000002344CD25FD0>)
# 2018-12-17 21:56:36.664311	开始回测
# 2018-12-17 21:56:36.664311	策略初始化
# 2018-12-17 21:56:36.665308	载入历史数据。数据范围:[20180824 04:00,20180901 12:00)
# 2018-12-17 21:56:37.186935	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:56:37.189955	载入完成，数据量：12000
# 2018-12-17 21:56:37.190953	策略初始化完成
# 2018-12-17 21:56:37.190953	策略启动完成
# 2018-12-17 21:56:37.190953	开始回放回测数据,回测范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:56:37.198930	载入历史数据。数据范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:56:42.510054	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:56:42.534986	载入完成，数据量：118890
# 2018-12-17 21:56:42.534986	当前回放数据:[20180901 12:00,20181123 12:00)
# [INFO] 品种BTCUSDT:binance开始生成未完成的1mK线数据,时间起点为:20180901120000
# 2018-12-17 21:56:42.536008	载入历史数据。数据范围:[20180831 20:51,20180903 12:01)
# 2018-12-17 21:56:42.714504	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:56:42.715533	载入完成，数据量：3790
# [INFO] 品种BTCUSDT:binance的历史1mK线更新，范围为:[20180901102100 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的1mK线准备就绪,当前K线时间为20180901120000
# [INFO] 品种BTCUSDT:binance开始生成未完成的60mK线数据,时间起点为:20180901120000
# 2018-12-17 21:56:42.731493	载入历史数据。数据范围:[20180725 15:00,20180831 20:50)
# 2018-12-17 21:56:45.007656	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:56:45.019660	载入完成，数据量：53630
# 2018-12-17 21:56:45.025610	载入历史数据。数据范围:[20180903 12:01,20180903 13:00)
# 2018-12-17 21:56:45.030610	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:56:45.030610	！！ 数据量为 0 ！！
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828080000 , 20180901110000]
# [INFO] 品种BTCUSDT:binance开始生成未完成的15mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831110000 , 20180901114500]
# [INFO] 品种BTCUSDT:binance开始生成1mK线数据,时间起点为:20180901120100
# [INFO] 品种BTCUSDT:binance开始生成60mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance开始生成15mK线数据,时间起点为:20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7054.86, 'close': 7059.99, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 381.507684, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831111500 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的15mK线准备就绪,当前K线时间为20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7039.8, 'close': 7054.02, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 1380.226004, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828090000 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的60mK线准备就绪,当前K线时间为20180901120000
# 2018-12-17 21:56:55.004941	数据回放结束ss: 100%
# 2018-12-17 21:56:55.004941	计算按日统计结果
# 2018-12-17 21:56:55.147557	------------------------------
# 2018-12-17 21:56:55.147557	setting: {'fastPeriod': 15, 'slowPeriod': 70, 'symbolList': ['BTCUSDT:binance']}
# 仓位字典构造完成
# 初始仓位: {'BTCUSDT:binance_LONG': 0, 'BTCUSDT:binance_SHORT': 0}
# [DEBUG] 注册品种BTCUSDT:binance上的on_60Min_bar函数functools.partial(<function MultiFrameMaStrategy.on60MinBar at 0x000002344EB0D730>, <__main__.MultiFrameMaStrategy object at 0x000002344BE6BF98>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_15Min_bar函数functools.partial(<function MultiFrameMaStrategy.on15MinBar at 0x000002344EB0D840>, <__main__.MultiFrameMaStrategy object at 0x000002344BE6BF98>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_1m_bar函数functools.partial(<function MultiFrameMaStrategy.onBar at 0x000002344EB0DF28>, <__main__.MultiFrameMaStrategy object at 0x000002344BE6BF98>)
# 2018-12-17 21:56:55.193435	开始回测
# 2018-12-17 21:56:55.193435	策略初始化
# 2018-12-17 21:56:55.194432	载入历史数据。数据范围:[20180824 04:00,20180901 12:00)
# 2018-12-17 21:56:55.812780	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:56:55.818764	载入完成，数据量：12000
# 2018-12-17 21:56:55.818764	策略初始化完成
# 2018-12-17 21:56:55.818764	策略启动完成
# 2018-12-17 21:56:55.818764	开始回放回测数据,回测范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:56:55.839708	载入历史数据。数据范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:57:02.700363	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:57:02.725296	载入完成，数据量：118890
# 2018-12-17 21:57:02.725296	当前回放数据:[20180901 12:00,20181123 12:00)
# [INFO] 品种BTCUSDT:binance开始生成未完成的1mK线数据,时间起点为:20180901120000
# 2018-12-17 21:57:02.726292	载入历史数据。数据范围:[20180831 20:51,20180903 12:01)
# 2018-12-17 21:57:03.058405	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:57:03.058405	载入完成，数据量：3790
# [INFO] 品种BTCUSDT:binance的历史1mK线更新，范围为:[20180901102100 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的1mK线准备就绪,当前K线时间为20180901120000
# [INFO] 品种BTCUSDT:binance开始生成未完成的60mK线数据,时间起点为:20180901120000
# 2018-12-17 21:57:03.076355	载入历史数据。数据范围:[20180725 15:00,20180831 20:50)
# 2018-12-17 21:57:06.473275	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:57:06.489233	载入完成，数据量：53630
# 2018-12-17 21:57:06.495215	载入历史数据。数据范围:[20180903 12:01,20180903 13:00)
# 2018-12-17 21:57:06.501199	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:57:06.501199	！！ 数据量为 0 ！！
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828080000 , 20180901110000]
# [INFO] 品种BTCUSDT:binance开始生成未完成的15mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831110000 , 20180901114500]
# [INFO] 品种BTCUSDT:binance开始生成1mK线数据,时间起点为:20180901120100
# [INFO] 品种BTCUSDT:binance开始生成60mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance开始生成15mK线数据,时间起点为:20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7054.86, 'close': 7059.99, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 381.507684, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831111500 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的15mK线准备就绪,当前K线时间为20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7039.8, 'close': 7054.02, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 1380.226004, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828090000 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的60mK线准备就绪,当前K线时间为20180901120000
# 2018-12-17 21:57:17.418915	数据回放结束ss: 100%
# 2018-12-17 21:57:17.418915	计算按日统计结果
# 2018-12-17 21:57:17.483622	------------------------------
# 2018-12-17 21:57:17.483622	setting: {'fastPeriod': 15, 'slowPeriod': 75, 'symbolList': ['BTCUSDT:binance']}
# 仓位字典构造完成
# 初始仓位: {'BTCUSDT:binance_LONG': 0, 'BTCUSDT:binance_SHORT': 0}
# [DEBUG] 注册品种BTCUSDT:binance上的on_60Min_bar函数functools.partial(<function MultiFrameMaStrategy.on60MinBar at 0x0000023444A56268>, <__main__.MultiFrameMaStrategy object at 0x000002344CC2BEB8>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_15Min_bar函数functools.partial(<function MultiFrameMaStrategy.on15MinBar at 0x0000023444A567B8>, <__main__.MultiFrameMaStrategy object at 0x000002344CC2BEB8>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_1m_bar函数functools.partial(<function MultiFrameMaStrategy.onBar at 0x0000023444A56158>, <__main__.MultiFrameMaStrategy object at 0x000002344CC2BEB8>)
# 2018-12-17 21:57:17.511547	开始回测
# 2018-12-17 21:57:17.511547	策略初始化
# 2018-12-17 21:57:17.512544	载入历史数据。数据范围:[20180824 04:00,20180901 12:00)
# 2018-12-17 21:57:18.029642	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:57:18.032633	载入完成，数据量：12000
# 2018-12-17 21:57:18.032633	策略初始化完成
# 2018-12-17 21:57:18.032633	策略启动完成
# 2018-12-17 21:57:18.032633	开始回放回测数据,回测范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:57:18.040612	载入历史数据。数据范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:57:23.781141	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:57:23.806106	载入完成，数据量：118890
# 2018-12-17 21:57:23.807071	当前回放数据:[20180901 12:00,20181123 12:00)
# [INFO] 品种BTCUSDT:binance开始生成未完成的1mK线数据,时间起点为:20180901120000
# 2018-12-17 21:57:23.808098	载入历史数据。数据范围:[20180831 20:51,20180903 12:01)
# 2018-12-17 21:57:23.985593	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:57:23.986590	载入完成，数据量：3790
# [INFO] 品种BTCUSDT:binance的历史1mK线更新，范围为:[20180901102100 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的1mK线准备就绪,当前K线时间为20180901120000
# [INFO] 品种BTCUSDT:binance开始生成未完成的60mK线数据,时间起点为:20180901120000
# 2018-12-17 21:57:24.003545	载入历史数据。数据范围:[20180725 15:00,20180831 20:50)
# 2018-12-17 21:57:26.435547	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:57:26.446522	载入完成，数据量：53630
# 2018-12-17 21:57:26.451505	载入历史数据。数据范围:[20180903 12:01,20180903 13:00)
# 2018-12-17 21:57:26.466708	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:57:26.466708	！！ 数据量为 0 ！！
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828080000 , 20180901110000]
# [INFO] 品种BTCUSDT:binance开始生成未完成的15mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831110000 , 20180901114500]
# [INFO] 品种BTCUSDT:binance开始生成1mK线数据,时间起点为:20180901120100
# [INFO] 品种BTCUSDT:binance开始生成60mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance开始生成15mK线数据,时间起点为:20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7054.86, 'close': 7059.99, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 381.507684, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831111500 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的15mK线准备就绪,当前K线时间为20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7039.8, 'close': 7054.02, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 1380.226004, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828090000 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的60mK线准备就绪,当前K线时间为20180901120000
# 2018-12-17 21:57:35.134141	数据回放结束ss: 100%
# 2018-12-17 21:57:35.134141	计算按日统计结果
# 2018-12-17 21:57:35.207877	------------------------------
# 2018-12-17 21:57:35.208874	setting: {'fastPeriod': 15, 'slowPeriod': 80, 'symbolList': ['BTCUSDT:binance']}
# 仓位字典构造完成
# 初始仓位: {'BTCUSDT:binance_LONG': 0, 'BTCUSDT:binance_SHORT': 0}
# [DEBUG] 注册品种BTCUSDT:binance上的on_60Min_bar函数functools.partial(<function MultiFrameMaStrategy.on60MinBar at 0x0000023444A56268>, <__main__.MultiFrameMaStrategy object at 0x000002344A2A9FD0>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_15Min_bar函数functools.partial(<function MultiFrameMaStrategy.on15MinBar at 0x000002344EB0D378>, <__main__.MultiFrameMaStrategy object at 0x000002344A2A9FD0>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_1m_bar函数functools.partial(<function MultiFrameMaStrategy.onBar at 0x0000023444A56158>, <__main__.MultiFrameMaStrategy object at 0x000002344A2A9FD0>)
# 2018-12-17 21:57:35.232809	开始回测
# 2018-12-17 21:57:35.232809	策略初始化
# 2018-12-17 21:57:35.233808	载入历史数据。数据范围:[20180824 04:00,20180901 12:00)
# 2018-12-17 21:57:35.729834	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:57:35.731832	载入完成，数据量：12000
# 2018-12-17 21:57:35.732831	策略初始化完成
# 2018-12-17 21:57:35.732831	策略启动完成
# 2018-12-17 21:57:35.732831	开始回放回测数据,回测范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:57:35.740808	载入历史数据。数据范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:57:41.014111	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:57:41.038075	载入完成，数据量：118890
# 2018-12-17 21:57:41.038075	当前回放数据:[20180901 12:00,20181123 12:00)
# [INFO] 品种BTCUSDT:binance开始生成未完成的1mK线数据,时间起点为:20180901120000
# 2018-12-17 21:57:41.040042	载入历史数据。数据范围:[20180831 20:51,20180903 12:01)
# 2018-12-17 21:57:41.377415	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:57:41.378411	载入完成，数据量：3790
# [INFO] 品种BTCUSDT:binance的历史1mK线更新，范围为:[20180901102100 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的1mK线准备就绪,当前K线时间为20180901120000
# [INFO] 品种BTCUSDT:binance开始生成未完成的60mK线数据,时间起点为:20180901120000
# 2018-12-17 21:57:41.396361	载入历史数据。数据范围:[20180725 15:00,20180831 20:50)
# 2018-12-17 21:57:43.831091	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:57:43.842097	载入完成，数据量：53630
# 2018-12-17 21:57:43.847077	载入历史数据。数据范围:[20180903 12:01,20180903 13:00)
# 2018-12-17 21:57:43.862290	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:57:43.862290	！！ 数据量为 0 ！！
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828080000 , 20180901110000]
# [INFO] 品种BTCUSDT:binance开始生成未完成的15mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831110000 , 20180901114500]
# [INFO] 品种BTCUSDT:binance开始生成1mK线数据,时间起点为:20180901120100
# [INFO] 品种BTCUSDT:binance开始生成60mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance开始生成15mK线数据,时间起点为:20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7054.86, 'close': 7059.99, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 381.507684, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831111500 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的15mK线准备就绪,当前K线时间为20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7039.8, 'close': 7054.02, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 1380.226004, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828090000 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的60mK线准备就绪,当前K线时间为20180901120000
# 2018-12-17 21:57:52.471263	数据回放结束ss: 100%
# 2018-12-17 21:57:52.471263	计算按日统计结果
# 2018-12-17 21:57:52.532100	------------------------------
# 2018-12-17 21:57:52.532100	setting: {'fastPeriod': 15, 'slowPeriod': 85, 'symbolList': ['BTCUSDT:binance']}
# 仓位字典构造完成
# 初始仓位: {'BTCUSDT:binance_LONG': 0, 'BTCUSDT:binance_SHORT': 0}
# [DEBUG] 注册品种BTCUSDT:binance上的on_60Min_bar函数functools.partial(<function MultiFrameMaStrategy.on60MinBar at 0x000002344EB0D1E0>, <__main__.MultiFrameMaStrategy object at 0x000002344942EF60>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_15Min_bar函数functools.partial(<function MultiFrameMaStrategy.on15MinBar at 0x000002344EB0D840>, <__main__.MultiFrameMaStrategy object at 0x000002344942EF60>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_1m_bar函数functools.partial(<function MultiFrameMaStrategy.onBar at 0x000002344EB0D158>, <__main__.MultiFrameMaStrategy object at 0x000002344942EF60>)
# 2018-12-17 21:57:52.554042	开始回测
# 2018-12-17 21:57:52.554042	策略初始化
# 2018-12-17 21:57:52.554042	载入历史数据。数据范围:[20180824 04:00,20180901 12:00)
# 2018-12-17 21:57:53.051422	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:57:53.054442	载入完成，数据量：12000
# 2018-12-17 21:57:53.054442	策略初始化完成
# 2018-12-17 21:57:53.054442	策略启动完成
# 2018-12-17 21:57:53.054442	开始回放回测数据,回测范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:57:53.062420	载入历史数据。数据范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:57:58.320337	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:57:58.352264	载入完成，数据量：118890
# 2018-12-17 21:57:58.352264	当前回放数据:[20180901 12:00,20181123 12:00)
# [INFO] 品种BTCUSDT:binance开始生成未完成的1mK线数据,时间起点为:20180901120000
# 2018-12-17 21:57:58.353242	载入历史数据。数据范围:[20180831 20:51,20180903 12:01)
# 2018-12-17 21:57:58.531765	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:57:58.532763	载入完成，数据量：3790
# [INFO] 品种BTCUSDT:binance的历史1mK线更新，范围为:[20180901102100 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的1mK线准备就绪,当前K线时间为20180901120000
# [INFO] 品种BTCUSDT:binance开始生成未完成的60mK线数据,时间起点为:20180901120000
# 2018-12-17 21:57:58.554702	载入历史数据。数据范围:[20180725 15:00,20180831 20:50)
# 2018-12-17 21:58:00.962394	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:58:00.974361	载入完成，数据量：53630
# 2018-12-17 21:58:00.979379	载入历史数据。数据范围:[20180903 12:01,20180903 13:00)
# 2018-12-17 21:58:00.995961	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:58:00.995961	！！ 数据量为 0 ！！
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828080000 , 20180901110000]
# [INFO] 品种BTCUSDT:binance开始生成未完成的15mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831110000 , 20180901114500]
# [INFO] 品种BTCUSDT:binance开始生成1mK线数据,时间起点为:20180901120100
# [INFO] 品种BTCUSDT:binance开始生成60mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance开始生成15mK线数据,时间起点为:20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7054.86, 'close': 7059.99, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 381.507684, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831111500 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的15mK线准备就绪,当前K线时间为20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7039.8, 'close': 7054.02, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 1380.226004, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828090000 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的60mK线准备就绪,当前K线时间为20180901120000
# 2018-12-17 21:58:09.613572	数据回放结束ss: 100%
# 2018-12-17 21:58:09.613572	计算按日统计结果
# 2018-12-17 21:58:09.687374	------------------------------
# 2018-12-17 21:58:09.687374	setting: {'fastPeriod': 15, 'slowPeriod': 90, 'symbolList': ['BTCUSDT:binance']}
# 仓位字典构造完成
# 初始仓位: {'BTCUSDT:binance_LONG': 0, 'BTCUSDT:binance_SHORT': 0}
# [DEBUG] 注册品种BTCUSDT:binance上的on_60Min_bar函数functools.partial(<function MultiFrameMaStrategy.on60MinBar at 0x000002344EB0D840>, <__main__.MultiFrameMaStrategy object at 0x0000023449A6ADA0>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_15Min_bar函数functools.partial(<function MultiFrameMaStrategy.on15MinBar at 0x000002344EB0D158>, <__main__.MultiFrameMaStrategy object at 0x0000023449A6ADA0>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_1m_bar函数functools.partial(<function MultiFrameMaStrategy.onBar at 0x000002344EB0D1E0>, <__main__.MultiFrameMaStrategy object at 0x0000023449A6ADA0>)
# 2018-12-17 21:58:09.712307	开始回测
# 2018-12-17 21:58:09.712307	策略初始化
# 2018-12-17 21:58:09.714302	载入历史数据。数据范围:[20180824 04:00,20180901 12:00)
# 2018-12-17 21:58:10.240897	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:58:10.243886	载入完成，数据量：12000
# 2018-12-17 21:58:10.243886	策略初始化完成
# 2018-12-17 21:58:10.243886	策略启动完成
# 2018-12-17 21:58:10.243886	开始回放回测数据,回测范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:58:10.252864	载入历史数据。数据范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:58:15.549882	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:58:15.574815	载入完成，数据量：118890
# 2018-12-17 21:58:15.574815	当前回放数据:[20180901 12:00,20181123 12:00)
# [INFO] 品种BTCUSDT:binance开始生成未完成的1mK线数据,时间起点为:20180901120000
# 2018-12-17 21:58:15.575812	载入历史数据。数据范围:[20180831 20:51,20180903 12:01)
# 2018-12-17 21:58:15.760535	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:58:15.761534	载入完成，数据量：3790
# [INFO] 品种BTCUSDT:binance的历史1mK线更新，范围为:[20180901102100 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的1mK线准备就绪,当前K线时间为20180901120000
# [INFO] 品种BTCUSDT:binance开始生成未完成的60mK线数据,时间起点为:20180901120000
# 2018-12-17 21:58:15.779519	载入历史数据。数据范围:[20180725 15:00,20180831 20:50)
# 2018-12-17 21:58:18.113641	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:58:18.123647	载入完成，数据量：53630
# 2018-12-17 21:58:18.128629	载入历史数据。数据范围:[20180903 12:01,20180903 13:00)
# 2018-12-17 21:58:18.143813	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:58:18.143813	！！ 数据量为 0 ！！
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828080000 , 20180901110000]
# [INFO] 品种BTCUSDT:binance开始生成未完成的15mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831110000 , 20180901114500]
# [INFO] 品种BTCUSDT:binance开始生成1mK线数据,时间起点为:20180901120100
# [INFO] 品种BTCUSDT:binance开始生成60mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance开始生成15mK线数据,时间起点为:20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7054.86, 'close': 7059.99, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 381.507684, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831111500 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的15mK线准备就绪,当前K线时间为20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7039.8, 'close': 7054.02, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 1380.226004, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828090000 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的60mK线准备就绪,当前K线时间为20180901120000
# 2018-12-17 21:58:26.890496	数据回放结束ss: 100%
# 2018-12-17 21:58:26.890496	计算按日统计结果
# 2018-12-17 21:58:26.962304	------------------------------
# 2018-12-17 21:58:26.962304	setting: {'fastPeriod': 15, 'slowPeriod': 95, 'symbolList': ['BTCUSDT:binance']}
# 仓位字典构造完成
# 初始仓位: {'BTCUSDT:binance_LONG': 0, 'BTCUSDT:binance_SHORT': 0}
# [DEBUG] 注册品种BTCUSDT:binance上的on_60Min_bar函数functools.partial(<function MultiFrameMaStrategy.on60MinBar at 0x0000023444A56158>, <__main__.MultiFrameMaStrategy object at 0x000002344AB71FD0>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_15Min_bar函数functools.partial(<function MultiFrameMaStrategy.on15MinBar at 0x000002344EB0D840>, <__main__.MultiFrameMaStrategy object at 0x000002344AB71FD0>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_1m_bar函数functools.partial(<function MultiFrameMaStrategy.onBar at 0x000002344EB0D158>, <__main__.MultiFrameMaStrategy object at 0x000002344AB71FD0>)
# 2018-12-17 21:58:26.987240	开始回测
# 2018-12-17 21:58:26.987240	策略初始化
# 2018-12-17 21:58:26.988235	载入历史数据。数据范围:[20180824 04:00,20180901 12:00)
# 2018-12-17 21:58:27.515285	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:58:27.518297	载入完成，数据量：12000
# 2018-12-17 21:58:27.518297	策略初始化完成
# 2018-12-17 21:58:27.518297	策略启动完成
# 2018-12-17 21:58:27.518297	开始回放回测数据,回测范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:58:27.527284	载入历史数据。数据范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:58:33.190353	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:58:33.215285	载入完成，数据量：118890
# 2018-12-17 21:58:33.215285	当前回放数据:[20180901 12:00,20181123 12:00)
# [INFO] 品种BTCUSDT:binance开始生成未完成的1mK线数据,时间起点为:20180901120000
# 2018-12-17 21:58:33.216283	载入历史数据。数据范围:[20180831 20:51,20180903 12:01)
# 2018-12-17 21:58:33.404132	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:58:33.405161	载入完成，数据量：3790
# [INFO] 品种BTCUSDT:binance的历史1mK线更新，范围为:[20180901102100 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的1mK线准备就绪,当前K线时间为20180901120000
# [INFO] 品种BTCUSDT:binance开始生成未完成的60mK线数据,时间起点为:20180901120000
# 2018-12-17 21:58:33.422114	载入历史数据。数据范围:[20180725 15:00,20180831 20:50)
# 2018-12-17 21:58:35.863674	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:58:35.875646	载入完成，数据量：53630
# 2018-12-17 21:58:35.882623	载入历史数据。数据范围:[20180903 12:01,20180903 13:00)
# 2018-12-17 21:58:35.888608	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:58:35.888608	！！ 数据量为 0 ！！
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828080000 , 20180901110000]
# [INFO] 品种BTCUSDT:binance开始生成未完成的15mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831110000 , 20180901114500]
# [INFO] 品种BTCUSDT:binance开始生成1mK线数据,时间起点为:20180901120100
# [INFO] 品种BTCUSDT:binance开始生成60mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance开始生成15mK线数据,时间起点为:20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7054.86, 'close': 7059.99, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 381.507684, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831111500 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的15mK线准备就绪,当前K线时间为20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7039.8, 'close': 7054.02, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 1380.226004, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828090000 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的60mK线准备就绪,当前K线时间为20180901120000
# 2018-12-17 21:58:44.193245	数据回放结束ss: 100%
# 2018-12-17 21:58:44.193245	计算按日统计结果
# 2018-12-17 21:58:44.255079	------------------------------
# 2018-12-17 21:58:44.255079	setting: {'fastPeriod': 15, 'slowPeriod': 100, 'symbolList': ['BTCUSDT:binance']}
# 仓位字典构造完成
# 初始仓位: {'BTCUSDT:binance_LONG': 0, 'BTCUSDT:binance_SHORT': 0}
# [DEBUG] 注册品种BTCUSDT:binance上的on_60Min_bar函数functools.partial(<function MultiFrameMaStrategy.on60MinBar at 0x0000023444A56158>, <__main__.MultiFrameMaStrategy object at 0x00000234493ACFD0>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_15Min_bar函数functools.partial(<function MultiFrameMaStrategy.on15MinBar at 0x000002344EB0D620>, <__main__.MultiFrameMaStrategy object at 0x00000234493ACFD0>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_1m_bar函数functools.partial(<function MultiFrameMaStrategy.onBar at 0x000002344EB0D9D8>, <__main__.MultiFrameMaStrategy object at 0x00000234493ACFD0>)
# 2018-12-17 21:58:44.277022	开始回测
# 2018-12-17 21:58:44.277022	策略初始化
# 2018-12-17 21:58:44.278045	载入历史数据。数据范围:[20180824 04:00,20180901 12:00)
# 2018-12-17 21:58:44.799933	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:58:44.802924	载入完成，数据量：12000
# 2018-12-17 21:58:44.802924	策略初始化完成
# 2018-12-17 21:58:44.802924	策略启动完成
# 2018-12-17 21:58:44.802924	开始回放回测数据,回测范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:58:44.811899	载入历史数据。数据范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:58:50.073320	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:58:50.105236	载入完成，数据量：118890
# 2018-12-17 21:58:50.105236	当前回放数据:[20180901 12:00,20181123 12:00)
# [INFO] 品种BTCUSDT:binance开始生成未完成的1mK线数据,时间起点为:20180901120000
# 2018-12-17 21:58:50.106230	载入历史数据。数据范围:[20180831 20:51,20180903 12:01)
# 2018-12-17 21:58:50.326461	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:58:50.326461	载入完成，数据量：3790
# [INFO] 品种BTCUSDT:binance的历史1mK线更新，范围为:[20180901102100 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的1mK线准备就绪,当前K线时间为20180901120000
# [INFO] 品种BTCUSDT:binance开始生成未完成的60mK线数据,时间起点为:20180901120000
# 2018-12-17 21:58:50.345445	载入历史数据。数据范围:[20180725 15:00,20180831 20:50)
# 2018-12-17 21:58:52.837517	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:58:52.848524	载入完成，数据量：53630
# 2018-12-17 21:58:52.854502	载入历史数据。数据范围:[20180903 12:01,20180903 13:00)
# 2018-12-17 21:58:52.869559	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:58:52.869559	！！ 数据量为 0 ！！
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828080000 , 20180901110000]
# [INFO] 品种BTCUSDT:binance开始生成未完成的15mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831110000 , 20180901114500]
# [INFO] 品种BTCUSDT:binance开始生成1mK线数据,时间起点为:20180901120100
# [INFO] 品种BTCUSDT:binance开始生成60mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance开始生成15mK线数据,时间起点为:20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7054.86, 'close': 7059.99, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 381.507684, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831111500 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的15mK线准备就绪,当前K线时间为20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7039.8, 'close': 7054.02, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 1380.226004, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828090000 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的60mK线准备就绪,当前K线时间为20180901120000
# 2018-12-17 21:59:01.158167	数据回放结束ss: 100%
# 2018-12-17 21:59:01.158167	计算按日统计结果
# 2018-12-17 21:59:01.221620	------------------------------
# 2018-12-17 21:59:01.221620	setting: {'fastPeriod': 18, 'slowPeriod': 40, 'symbolList': ['BTCUSDT:binance']}
# 仓位字典构造完成
# 初始仓位: {'BTCUSDT:binance_LONG': 0, 'BTCUSDT:binance_SHORT': 0}
# [DEBUG] 注册品种BTCUSDT:binance上的on_60Min_bar函数functools.partial(<function MultiFrameMaStrategy.on60MinBar at 0x000002344EB0D598>, <__main__.MultiFrameMaStrategy object at 0x000002344D4EFFD0>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_15Min_bar函数functools.partial(<function MultiFrameMaStrategy.on15MinBar at 0x000002344EB0D950>, <__main__.MultiFrameMaStrategy object at 0x000002344D4EFFD0>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_1m_bar函数functools.partial(<function MultiFrameMaStrategy.onBar at 0x000002344EB0D0D0>, <__main__.MultiFrameMaStrategy object at 0x000002344D4EFFD0>)
# 2018-12-17 21:59:01.247539	开始回测
# 2018-12-17 21:59:01.247539	策略初始化
# 2018-12-17 21:59:01.248537	载入历史数据。数据范围:[20180824 04:00,20180901 12:00)
# 2018-12-17 21:59:01.826623	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 21:59:01.829611	载入完成，数据量：12000
# 2018-12-17 21:59:01.829611	策略初始化完成
# 2018-12-17 21:59:01.829611	策略启动完成
# 2018-12-17 21:59:01.829611	开始回放回测数据,回测范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:59:01.837590	载入历史数据。数据范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 21:59:07.019626	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# ...
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831111500 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的15mK线准备就绪,当前K线时间为20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7039.8, 'close': 7054.02, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 1380.226004, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828090000 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的60mK线准备就绪,当前K线时间为20180901120000
# 2018-12-17 22:21:11.790408	数据回放结束ss: 100%
# 2018-12-17 22:21:11.790408	计算按日统计结果
# 2018-12-17 22:21:11.851242	------------------------------
# 2018-12-17 22:21:11.852209	setting: {'fastPeriod': 33, 'slowPeriod': 100, 'symbolList': ['BTCUSDT:binance']}
# 仓位字典构造完成
# 初始仓位: {'BTCUSDT:binance_LONG': 0, 'BTCUSDT:binance_SHORT': 0}
# [DEBUG] 注册品种BTCUSDT:binance上的on_60Min_bar函数functools.partial(<function MultiFrameMaStrategy.on60MinBar at 0x000002344EB0D950>, <__main__.MultiFrameMaStrategy object at 0x000002344B3D0F28>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_15Min_bar函数functools.partial(<function MultiFrameMaStrategy.on15MinBar at 0x000002344EB0D620>, <__main__.MultiFrameMaStrategy object at 0x000002344B3D0F28>)
# [DEBUG] 注册品种BTCUSDT:binance上的on_1m_bar函数functools.partial(<function MultiFrameMaStrategy.onBar at 0x000002344EB0D488>, <__main__.MultiFrameMaStrategy object at 0x000002344B3D0F28>)
# 2018-12-17 22:21:11.871156	开始回测
# 2018-12-17 22:21:11.871156	策略初始化
# 2018-12-17 22:21:11.872183	载入历史数据。数据范围:[20180824 04:00,20180901 12:00)
# 2018-12-17 22:21:12.450624	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 22:21:12.458600	载入完成，数据量：12000
# 2018-12-17 22:21:12.458600	策略初始化完成
# 2018-12-17 22:21:12.458600	策略启动完成
# 2018-12-17 22:21:12.458600	开始回放回测数据,回测范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 22:21:12.467579	载入历史数据。数据范围:[20180901 12:00,20181123 12:00)
# 2018-12-17 22:21:18.984137	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 22:21:19.011101	载入完成，数据量：118890
# 2018-12-17 22:21:19.012063	当前回放数据:[20180901 12:00,20181123 12:00)
# [INFO] 品种BTCUSDT:binance开始生成未完成的1mK线数据,时间起点为:20180901120000
# 2018-12-17 22:21:19.013061	载入历史数据。数据范围:[20180831 20:51,20180903 12:01)
# 2018-12-17 22:21:19.210534	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 22:21:19.210534	载入完成，数据量：3790
# [INFO] 品种BTCUSDT:binance的历史1mK线更新，范围为:[20180901102100 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的1mK线准备就绪,当前K线时间为20180901120000
# [INFO] 品种BTCUSDT:binance开始生成未完成的60mK线数据,时间起点为:20180901120000
# 2018-12-17 22:21:19.228517	载入历史数据。数据范围:[20180725 15:00,20180831 20:50)
# 2018-12-17 22:21:21.853466	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 22:21:21.863438	载入完成，数据量：53630
# 2018-12-17 22:21:21.869422	载入历史数据。数据范围:[20180903 12:01,20180903 13:00)
# 2018-12-17 22:21:21.874413	 当前品种 BTCUSDT:binance 的数据，全部来自于本地缓存
# 2018-12-17 22:21:21.874413	！！ 数据量为 0 ！！
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828080000 , 20180901110000]
# [INFO] 品种BTCUSDT:binance开始生成未完成的15mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831110000 , 20180901114500]
# [INFO] 品种BTCUSDT:binance开始生成1mK线数据,时间起点为:20180901120100
# [INFO] 品种BTCUSDT:binance开始生成60mK线数据,时间起点为:20180901120000
# [INFO] 品种BTCUSDT:binance开始生成15mK线数据,时间起点为:20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7054.86, 'close': 7059.99, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 381.507684, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史15mK线更新，范围为:[20180831111500 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的15mK线准备就绪,当前K线时间为20180901120000
# [DEBUG] merged bar {'gatewayName': '', 'rawData': None, 'vtSymbol': 'BTCUSDT:binance', 'symbol': 'BTCUSDT', 'exchange': 'binance', 'open': 7067.17, 'high': 7079.0, 'low': 7039.8, 'close': 7054.02, 'date': '20180901', 'time': '12:00:00.000000', 'datetime': datetime.datetime(2018, 9, 1, 12, 0), 'volume': 1380.226004, 'openInterest': 0}
# [INFO] 品种BTCUSDT:binance的历史60mK线更新，范围为:[20180828090000 , 20180901120000]
# [INFO] 品种BTCUSDT:binance的60mK线准备就绪,当前K线时间为20180901120000
# 2018-12-17 22:21:30.875309	数据回放结束ss: 100%
# 2018-12-17 22:21:30.875309	计算按日统计结果
# 2018-12-17 22:21:30.920161	------------------------------
# 2018-12-17 22:21:30.920161	优化结果：
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 33, 'slowPeriod': 55, 'symbolList': ['BTCUSDT:binance']}"]，目标：4.279196264792196
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 15, 'slowPeriod': 45, 'symbolList': ['BTCUSDT:binance']}"]，目标：4.021391008714355
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 18, 'slowPeriod': 45, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.999882945047004
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 21, 'slowPeriod': 55, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.972520410574871
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 21, 'slowPeriod': 45, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.940883436255489
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 24, 'slowPeriod': 45, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.906490113031809
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 30, 'slowPeriod': 45, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.888709879268264
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 15, 'slowPeriod': 40, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.830481278659575
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 27, 'slowPeriod': 45, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.7630479274952067
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 18, 'slowPeriod': 50, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.748174912079778
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 21, 'slowPeriod': 50, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.730448688991591
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 21, 'slowPeriod': 60, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.729466936636745
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 18, 'slowPeriod': 40, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.71997491643264
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 24, 'slowPeriod': 55, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.7133100102863126
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 18, 'slowPeriod': 55, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.6904697416237155
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 33, 'slowPeriod': 45, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.6799169465459127
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 30, 'slowPeriod': 40, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.6425674453940045
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 33, 'slowPeriod': 40, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.5943813185318425
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 21, 'slowPeriod': 75, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.5683869106364936
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 15, 'slowPeriod': 55, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.5672398855844705
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 27, 'slowPeriod': 55, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.527383830540028
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 18, 'slowPeriod': 75, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.524185543492182
# 2018-12-17 22:21:30.920161	参数：["{'fastPeriod': 21, 'slowPeriod': 80, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.5013583866171616
# 2018-12-17 22:21:30.921158	参数：["{'fastPeriod': 18, 'slowPeriod': 70, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.4884160179193624
# 2018-12-17 22:21:30.921158	参数：["{'fastPeriod': 24, 'slowPeriod': 60, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.4683320696332096
# 2018-12-17 22:21:30.921158	参数：["{'fastPeriod': 21, 'slowPeriod': 70, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.4647461968102298
# 2018-12-17 22:21:30.921158	参数：["{'fastPeriod': 21, 'slowPeriod': 65, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.450721789846789
# 2018-12-17 22:21:30.921158	参数：["{'fastPeriod': 18, 'slowPeriod': 80, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.4350235195203966
# 2018-12-17 22:21:30.921158	参数：["{'fastPeriod': 18, 'slowPeriod': 85, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.4108051361439493
# 2018-12-17 22:21:30.921158	参数：["{'fastPeriod': 18, 'slowPeriod': 65, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.316588493881783
# 2018-12-17 22:21:30.921158	参数：["{'fastPeriod': 21, 'slowPeriod': 90, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.250251946871682
# 2018-12-17 22:21:30.921158	参数：["{'fastPeriod': 15, 'slowPeriod': 75, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.2443907496758886
# 2018-12-17 22:21:30.921158	参数：["{'fastPeriod': 30, 'slowPeriod': 55, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.2098802635538073
# 2018-12-17 22:21:30.921158	参数：["{'fastPeriod': 24, 'slowPeriod': 70, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.1759837668648636
# 2018-12-17 22:21:30.921158	参数：["{'fastPeriod': 24, 'slowPeriod': 80, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.1419717724425924
# 2018-12-17 22:21:30.921158	参数：["{'fastPeriod': 15, 'slowPeriod': 70, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.1338270570781823
# 2018-12-17 22:21:30.921158	参数：["{'fastPeriod': 18, 'slowPeriod': 100, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.1189977711756645
# 2018-12-17 22:21:30.921158	参数：["{'fastPeriod': 24, 'slowPeriod': 50, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.1161746483257273
# 2018-12-17 22:21:30.922158	参数：["{'fastPeriod': 15, 'slowPeriod': 50, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.0935886331686047
# 2018-12-17 22:21:30.922158	参数：["{'fastPeriod': 33, 'slowPeriod': 80, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.090179142646781
# 2018-12-17 22:21:30.922158	参数：["{'fastPeriod': 21, 'slowPeriod': 40, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.0869491409342116
# 2018-12-17 22:21:30.922158	参数：["{'fastPeriod': 15, 'slowPeriod': 65, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.079650843870491
# 2018-12-17 22:21:30.922158	参数：["{'fastPeriod': 15, 'slowPeriod': 100, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.0786340336085
# 2018-12-17 22:21:30.922158	参数：["{'fastPeriod': 27, 'slowPeriod': 80, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.0357252009304982
# 2018-12-17 22:21:30.922158	参数：["{'fastPeriod': 27, 'slowPeriod': 60, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.982052782937428
# 2018-12-17 22:21:30.922158	参数：["{'fastPeriod': 21, 'slowPeriod': 85, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.979107117325508
# 2018-12-17 22:21:30.922158	参数：["{'fastPeriod': 33, 'slowPeriod': 85, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.968074941010068
# 2018-12-17 22:21:30.922158	参数：["{'fastPeriod': 21, 'slowPeriod': 100, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.967453537642421
# 2018-12-17 22:21:30.922158	参数：["{'fastPeriod': 18, 'slowPeriod': 95, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.965003679492184
# 2018-12-17 22:21:30.922158	参数：["{'fastPeriod': 30, 'slowPeriod': 80, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.9456588639684242
# 2018-12-17 22:21:30.922158	参数：["{'fastPeriod': 18, 'slowPeriod': 90, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.9379554326275747
# 2018-12-17 22:21:30.922158	参数：["{'fastPeriod': 24, 'slowPeriod': 75, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.924738877881142
# 2018-12-17 22:21:30.922158	参数：["{'fastPeriod': 30, 'slowPeriod': 60, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.919579847922548
# 2018-12-17 22:21:30.922158	参数：["{'fastPeriod': 18, 'slowPeriod': 60, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.8926117544202143
# 2018-12-17 22:21:30.922158	参数：["{'fastPeriod': 27, 'slowPeriod': 50, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.88913578267928
# 2018-12-17 22:21:30.922158	参数：["{'fastPeriod': 15, 'slowPeriod': 90, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.867627434343833
# 2018-12-17 22:21:30.922158	参数：["{'fastPeriod': 27, 'slowPeriod': 70, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.8621786448892315
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 15, 'slowPeriod': 95, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.860250234541673
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 15, 'slowPeriod': 80, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.8276696465234363
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 15, 'slowPeriod': 60, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.8219252889541417
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 33, 'slowPeriod': 60, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.812781779604323
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 30, 'slowPeriod': 85, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.8123279514925947
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 24, 'slowPeriod': 65, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.7966342952662226
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 21, 'slowPeriod': 95, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.78401939257501
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 27, 'slowPeriod': 75, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.781853241895962
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 30, 'slowPeriod': 50, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.749902028172871
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 27, 'slowPeriod': 85, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.746099173393178
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 30, 'slowPeriod': 75, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.67680408915241
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 24, 'slowPeriod': 100, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.635307124046461
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 24, 'slowPeriod': 40, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.61944969698895
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 24, 'slowPeriod': 95, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.612288755646725
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 24, 'slowPeriod': 85, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.5959909108908987
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 27, 'slowPeriod': 65, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.5815406446226548
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 33, 'slowPeriod': 90, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.5561881098679415
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 33, 'slowPeriod': 75, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.5354854971579184
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 30, 'slowPeriod': 65, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.498291417775392
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 27, 'slowPeriod': 100, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.4872462996848825
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 24, 'slowPeriod': 90, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.471801199002425
# 2018-12-17 22:21:30.923153	参数：["{'fastPeriod': 27, 'slowPeriod': 95, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.4396618677965485
# 2018-12-17 22:21:30.924151	参数：["{'fastPeriod': 33, 'slowPeriod': 70, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.4252617520234296
# 2018-12-17 22:21:30.924151	参数：["{'fastPeriod': 33, 'slowPeriod': 65, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.3597082841008934
# 2018-12-17 22:21:30.924151	参数：["{'fastPeriod': 33, 'slowPeriod': 100, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.303586137525792
# 2018-12-17 22:21:30.924151	参数：["{'fastPeriod': 33, 'slowPeriod': 50, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.25808393790099
# 2018-12-17 22:21:30.924151	参数：["{'fastPeriod': 30, 'slowPeriod': 70, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.2430091745719922
# 2018-12-17 22:21:30.924151	参数：["{'fastPeriod': 30, 'slowPeriod': 95, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.239560742376177
# 2018-12-17 22:21:30.924151	参数：["{'fastPeriod': 15, 'slowPeriod': 85, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.2062233658157404
# 2018-12-17 22:21:30.924151	参数：["{'fastPeriod': 30, 'slowPeriod': 100, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.205449916058595
# 2018-12-17 22:21:30.924151	参数：["{'fastPeriod': 27, 'slowPeriod': 90, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.201298277951344
# 2018-12-17 22:21:30.924151	参数：["{'fastPeriod': 33, 'slowPeriod': 95, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.0100742425192877
# 2018-12-17 22:21:30.924151	参数：["{'fastPeriod': 30, 'slowPeriod': 90, 'symbolList': ['BTCUSDT:binance']}"]，目标：1.986144949028892
# 2018-12-17 22:21:30.924151	参数：["{'fastPeriod': 27, 'slowPeriod': 40, 'symbolList': ['BTCUSDT:binance']}"]，目标：1.6445039844247744
# 耗时：1582.2887661457062

# %% [markdown]
# ### 打印最优结果排序的DataFrame

# %%
import pandas as pd

print(pd.DataFrame(resultList).sort_values(1,  ascending=False))
# Out:
#                                                     0         1  \
# 0   [{'fastPeriod': 33, 'slowPeriod': 55, 'symbolL...  4.279196
# 1   [{'fastPeriod': 15, 'slowPeriod': 45, 'symbolL...  4.021391
# 2   [{'fastPeriod': 18, 'slowPeriod': 45, 'symbolL...  3.999883
# 3   [{'fastPeriod': 21, 'slowPeriod': 55, 'symbolL...  3.972520
# 4   [{'fastPeriod': 21, 'slowPeriod': 45, 'symbolL...  3.940883
# 5   [{'fastPeriod': 24, 'slowPeriod': 45, 'symbolL...  3.906490
# 6   [{'fastPeriod': 30, 'slowPeriod': 45, 'symbolL...  3.888710
# 7   [{'fastPeriod': 15, 'slowPeriod': 40, 'symbolL...  3.830481
# 8   [{'fastPeriod': 27, 'slowPeriod': 45, 'symbolL...  3.763048
# 9   [{'fastPeriod': 18, 'slowPeriod': 50, 'symbolL...  3.748175
# 10  [{'fastPeriod': 21, 'slowPeriod': 50, 'symbolL...  3.730449
# 11  [{'fastPeriod': 21, 'slowPeriod': 60, 'symbolL...  3.729467
# 12  [{'fastPeriod': 18, 'slowPeriod': 40, 'symbolL...  3.719975
# 13  [{'fastPeriod': 24, 'slowPeriod': 55, 'symbolL...  3.713310
# 14  [{'fastPeriod': 18, 'slowPeriod': 55, 'symbolL...  3.690470
# 15  [{'fastPeriod': 33, 'slowPeriod': 45, 'symbolL...  3.679917
# 16  [{'fastPeriod': 30, 'slowPeriod': 40, 'symbolL...  3.642567
# 17  [{'fastPeriod': 33, 'slowPeriod': 40, 'symbolL...  3.594381
# 18  [{'fastPeriod': 21, 'slowPeriod': 75, 'symbolL...  3.568387
# 19  [{'fastPeriod': 15, 'slowPeriod': 55, 'symbolL...  3.567240
# 20  [{'fastPeriod': 27, 'slowPeriod': 55, 'symbolL...  3.527384
# 21  [{'fastPeriod': 18, 'slowPeriod': 75, 'symbolL...  3.524186
# 22  [{'fastPeriod': 21, 'slowPeriod': 80, 'symbolL...  3.501358
# 23  [{'fastPeriod': 18, 'slowPeriod': 70, 'symbolL...  3.488416
# 24  [{'fastPeriod': 24, 'slowPeriod': 60, 'symbolL...  3.468332
# 25  [{'fastPeriod': 21, 'slowPeriod': 70, 'symbolL...  3.464746
# 26  [{'fastPeriod': 21, 'slowPeriod': 65, 'symbolL...  3.450722
# 27  [{'fastPeriod': 18, 'slowPeriod': 80, 'symbolL...  3.435024
# 28  [{'fastPeriod': 18, 'slowPeriod': 85, 'symbolL...  3.410805
# 29  [{'fastPeriod': 18, 'slowPeriod': 65, 'symbolL...  3.316588
# ..                                                ...       ...
# 61  [{'fastPeriod': 30, 'slowPeriod': 85, 'symbolL...  2.812328
# 62  [{'fastPeriod': 24, 'slowPeriod': 65, 'symbolL...  2.796634
# 63  [{'fastPeriod': 21, 'slowPeriod': 95, 'symbolL...  2.784019
# 64  [{'fastPeriod': 27, 'slowPeriod': 75, 'symbolL...  2.781853
# 65  [{'fastPeriod': 30, 'slowPeriod': 50, 'symbolL...  2.749902
# 66  [{'fastPeriod': 27, 'slowPeriod': 85, 'symbolL...  2.746099
# 67  [{'fastPeriod': 30, 'slowPeriod': 75, 'symbolL...  2.676804
# 68  [{'fastPeriod': 24, 'slowPeriod': 100, 'symbol...  2.635307
# 69  [{'fastPeriod': 24, 'slowPeriod': 40, 'symbolL...  2.619450
# 70  [{'fastPeriod': 24, 'slowPeriod': 95, 'symbolL...  2.612289
# 71  [{'fastPeriod': 24, 'slowPeriod': 85, 'symbolL...  2.595991
# 72  [{'fastPeriod': 27, 'slowPeriod': 65, 'symbolL...  2.581541
# 73  [{'fastPeriod': 33, 'slowPeriod': 90, 'symbolL...  2.556188
# 74  [{'fastPeriod': 33, 'slowPeriod': 75, 'symbolL...  2.535485
# 75  [{'fastPeriod': 30, 'slowPeriod': 65, 'symbolL...  2.498291
# 76  [{'fastPeriod': 27, 'slowPeriod': 100, 'symbol...  2.487246
# 77  [{'fastPeriod': 24, 'slowPeriod': 90, 'symbolL...  2.471801
# 78  [{'fastPeriod': 27, 'slowPeriod': 95, 'symbolL...  2.439662
# 79  [{'fastPeriod': 33, 'slowPeriod': 70, 'symbolL...  2.425262
# 80  [{'fastPeriod': 33, 'slowPeriod': 65, 'symbolL...  2.359708
# 81  [{'fastPeriod': 33, 'slowPeriod': 100, 'symbol...  2.303586
# 82  [{'fastPeriod': 33, 'slowPeriod': 50, 'symbolL...  2.258084
# 83  [{'fastPeriod': 30, 'slowPeriod': 70, 'symbolL...  2.243009
# 84  [{'fastPeriod': 30, 'slowPeriod': 95, 'symbolL...  2.239561
# 85  [{'fastPeriod': 15, 'slowPeriod': 85, 'symbolL...  2.206223
# 86  [{'fastPeriod': 30, 'slowPeriod': 100, 'symbol...  2.205450
# 87  [{'fastPeriod': 27, 'slowPeriod': 90, 'symbolL...  2.201298
# 88  [{'fastPeriod': 33, 'slowPeriod': 95, 'symbolL...  2.010074
# 89  [{'fastPeriod': 30, 'slowPeriod': 90, 'symbolL...  1.986145
# 90  [{'fastPeriod': 27, 'slowPeriod': 40, 'symbolL...  1.644504
#
#                                                     2
# 0   {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 1   {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 2   {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 3   {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 4   {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 5   {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 6   {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 7   {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 8   {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 9   {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 10  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 11  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 12  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 13  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 14  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 15  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 16  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 17  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 18  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 19  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 20  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 21  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 22  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 23  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 24  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 25  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 26  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 27  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 28  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 29  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# ..                                                ...
# 61  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 62  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 63  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 64  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 65  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 66  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 67  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 68  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 69  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 70  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 71  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 72  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 73  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 74  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 75  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 76  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 77  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 78  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 79  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 80  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 81  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 82  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 83  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 84  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 85  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 86  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 87  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 88  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 89  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
# 90  {'startDate': 2018-09-01 00:00:00, 'endDate': ...
#
# [91 rows x 3 columns]

# %%
# 显示优化的所有统计数据
for result in resultList:
    print('-' * 30)
    print('参数：%s，目标：%s' %(result[0], result[1]))
    print('统计数据：')
    for k, v in result[2].items():
        print('%s：%s' %(k, v))
# Out:
# ------------------------------
# 参数：["{'fastPeriod': 33, 'slowPeriod': 55, 'symbolList': ['BTCUSDT:binance']}"]，目标：4.279196264792196
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：48
# lossDays：35
# endBalance：1002659.68416
# maxDrawdown：-867.3808599999174
# maxDdPercent：-0.08698991800681256
# totalNetPnl：2659.684159999991
# dailyNetPnl：31.66290666666656
# totalCommission：251.84784000000002
# dailyCommission：2.998188571428572
# totalSlippage：0.158
# dailySlippage：0.001880952380952381
# totalTurnover：503695.68000000005
# dailyTurnover：5996.377142857144
# totalTradeCount：79
# dailyTradeCount：0.9404761904761905
# totalReturn：0.2659684159999953
# annualizedReturn：0.7599097599999866
# dailyReturn：0.00982127162024462
# returnStd：0.03555585588513231
# sharpeRatio：4.279196264792196
# ------------------------------
# 参数：["{'fastPeriod': 15, 'slowPeriod': 45, 'symbolList': ['BTCUSDT:binance']}"]，目标：4.021391008714355
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：44
# lossDays：39
# endBalance：1002555.39058
# maxDrawdown：-894.5389300000388
# maxDdPercent：-0.08974261179812906
# totalNetPnl：2555.3905800000007
# dailyNetPnl：30.421316428571437
# totalCommission：278.36542
# dailyCommission：3.313874047619047
# totalSlippage：0.17400000000000002
# dailySlippage：0.0020714285714285717
# totalTurnover：556730.84
# dailyTurnover：6627.748095238095
# totalTradeCount：87
# dailyTradeCount：1.0357142857142858
# totalReturn：0.2555390579999983
# annualizedReturn：0.7301115942857095
# dailyReturn：0.009697435503624214
# returnStd：0.03735822368436087
# sharpeRatio：4.021391008714355
# ------------------------------
# 参数：["{'fastPeriod': 18, 'slowPeriod': 45, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.999882945047004
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：47
# lossDays：36
# endBalance：1002561.05778
# maxDrawdown：-857.4204900000477
# maxDdPercent：-0.08601328072484807
# totalNetPnl：2561.0577800000037
# dailyNetPnl：30.48878309523814
# totalCommission：287.73022000000003
# dailyCommission：3.425359761904762
# totalSlippage：0.18200000000000005
# dailySlippage：0.0021666666666666674
# totalTurnover：575460.44
# dailyTurnover：6850.719523809523
# totalTradeCount：91
# dailyTradeCount：1.0833333333333333
# totalReturn：0.2561057779999931
# annualizedReturn：0.7317307942856945
# dailyReturn：0.009704164954846934
# returnStd：0.03758516914152363
# sharpeRatio：3.999882945047004
# ------------------------------
# 参数：["{'fastPeriod': 21, 'slowPeriod': 55, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.972520410574871
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：51
# lossDays：31
# endBalance：1003105.76505
# maxDrawdown：-308.7471000000369
# maxDdPercent：-0.0308648227321335
# totalNetPnl：3105.7650499999977
# dailyNetPnl：36.973393452380925
# totalCommission：230.16295000000002
# dailyCommission：2.7400351190476195
# totalSlippage：0.14200000000000002
# dailySlippage：0.0016904761904761906
# totalTurnover：460325.9
# dailyTurnover：5480.070238095238
# totalTradeCount：71
# dailyTradeCount：0.8452380952380952
# totalReturn：0.3105765050000153
# annualizedReturn：0.8873614428571867
# dailyReturn：0.003561877467093767
# returnStd：0.013890518547935469
# sharpeRatio：3.972520410574871
# ------------------------------
# 参数：["{'fastPeriod': 21, 'slowPeriod': 45, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.940883436255489
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：47
# lossDays：36
# endBalance：1002421.24215
# maxDrawdown：-877.9674200000009
# maxDdPercent：-0.08808449131083722
# totalNetPnl：2421.2421500000023
# dailyNetPnl：28.824311309523836
# totalCommission：299.83785
# dailyCommission：3.5694982142857143
# totalSlippage：0.19000000000000003
# dailySlippage：0.0022619047619047623
# totalTurnover：599675.7000000001
# dailyTurnover：7138.9964285714295
# totalTradeCount：95
# dailyTradeCount：1.130952380952381
# totalReturn：0.2421242150000058
# annualizedReturn：0.6917834714285881
# dailyReturn：0.009538131390512697
# returnStd：0.03749517043771702
# sharpeRatio：3.940883436255489
# ------------------------------
# 参数：["{'fastPeriod': 24, 'slowPeriod': 45, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.906490113031809
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：48
# lossDays：35
# endBalance：1002323.94632
# maxDrawdown：-772.3984600000549
# maxDdPercent：-0.07748660988030141
# totalNetPnl：2323.9463199999977
# dailyNetPnl：27.666027619047593
# totalCommission：327.01768
# dailyCommission：3.8930676190476188
# totalSlippage：0.20600000000000002
# dailySlippage：0.0024523809523809524
# totalTurnover：654035.36
# dailyTurnover：7786.135238095238
# totalTradeCount：103
# dailyTradeCount：1.2261904761904763
# totalReturn：0.2323946319999992
# annualizedReturn：0.6639846628571405
# dailyReturn：0.009422577184617762
# returnStd：0.03736703123106705
# sharpeRatio：3.906490113031809
# ------------------------------
# 参数：["{'fastPeriod': 30, 'slowPeriod': 45, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.888709879268264
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：48
# lossDays：35
# endBalance：1002103.23301
# maxDrawdown：-848.1347700000042
# maxDdPercent：-0.08507222151770187
# totalNetPnl：2103.233009999997
# dailyNetPnl：25.03848821428568
# totalCommission：328.27099000000004
# dailyCommission：3.9079879761904768
# totalSlippage：0.20600000000000002
# dailySlippage：0.0024523809523809524
# totalTurnover：656541.98
# dailyTurnover：7815.975952380953
# totalTradeCount：103
# dailyTradeCount：1.2261904761904763
# totalReturn：0.21032330099999275
# annualizedReturn：0.6009237171428364
# dailyReturn：0.009160403587842631
# returnStd：0.03649343010070895
# sharpeRatio：3.888709879268264
# ------------------------------
# 参数：["{'fastPeriod': 15, 'slowPeriod': 40, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.830481278659575
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：43
# lossDays：40
# endBalance：1002169.05629
# maxDrawdown：-816.9227899999823
# maxDdPercent：-0.08197437725311292
# totalNetPnl：2169.0562899999977
# dailyNetPnl：25.822098690476164
# totalCommission：378.49571000000003
# dailyCommission：4.50590130952381
# totalSlippage：0.23800000000000004
# dailySlippage：0.002833333333333334
# totalTurnover：756991.42
# dailyTurnover：9011.80261904762
# totalTradeCount：119
# dailyTradeCount：1.4166666666666667
# totalReturn：0.2169056290000082
# annualizedReturn：0.619730368571452
# dailyReturn：0.009238597601766787
# returnStd：0.03736442713170038
# sharpeRatio：3.830481278659575
# ------------------------------
# 参数：["{'fastPeriod': 27, 'slowPeriod': 45, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.7630479274952067
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：48
# lossDays：35
# endBalance：1002037.15391
# maxDrawdown：-764.9484199999133
# maxDdPercent：-0.07674422433081578
# totalNetPnl：2037.1539099999964
# dailyNetPnl：24.251832261904717
# totalCommission：351.89409000000006
# dailyCommission：4.189215357142858
# totalSlippage：0.22200000000000003
# dailySlippage：0.0026428571428571434
# totalTurnover：703788.18
# dailyTurnover：8378.430714285714
# totalTradeCount：111
# dailyTradeCount：1.3214285714285714
# totalReturn：0.20371539099999225
# annualizedReturn：0.5820439742856922
# dailyReturn：0.009081900509136242
# returnStd：0.037388893366776955
# sharpeRatio：3.7630479274952067
# ------------------------------
# 参数：["{'fastPeriod': 18, 'slowPeriod': 50, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.748174912079778
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：52
# lossDays：30
# endBalance：1003077.64052
# maxDrawdown：-406.0634400000563
# maxDdPercent：-0.04055737406413411
# totalNetPnl：3077.640519999998
# dailyNetPnl：36.638577619047595
# totalCommission：230.30748
# dailyCommission：2.741755714285714
# totalSlippage：0.14200000000000002
# dailySlippage：0.0016904761904761906
# totalTurnover：460614.96
# dailyTurnover：5483.511428571429
# totalTradeCount：71
# dailyTradeCount：0.8452380952380952
# totalReturn：0.30776405199999246
# annualizedReturn：0.8793258628571213
# dailyReturn：0.0035284990798121305
# returnStd：0.014583970592383824
# sharpeRatio：3.748174912079778
# ------------------------------
# 参数：["{'fastPeriod': 21, 'slowPeriod': 50, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.730448688991591
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：50
# lossDays：32
# endBalance：1002966.79302
# maxDrawdown：-308.7471000000369
# maxDdPercent：-0.0308648227321335
# totalNetPnl：2966.793020000003
# dailyNetPnl：35.318964523809555
# totalCommission：257.17898
# dailyCommission：3.061654523809524
# totalSlippage：0.15800000000000003
# dailySlippage：0.0018809523809523814
# totalTurnover：514357.95999999996
# dailyTurnover：6123.309047619047
# totalTradeCount：79
# dailyTradeCount：0.9404761904761905
# totalReturn：0.2966793019999914
# annualizedReturn：0.847655148571404
# dailyReturn：0.0033969353841600295
# returnStd：0.014106908061561755
# sharpeRatio：3.730448688991591
# ------------------------------
# 参数：["{'fastPeriod': 21, 'slowPeriod': 60, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.729466936636745
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：47
# lossDays：35
# endBalance：1002944.51046
# maxDrawdown：-331.90661000006367
# maxDdPercent：-0.03314728910076136
# totalNetPnl：2944.510459999997
# dailyNetPnl：35.05369595238091
# totalCommission：216.72554000000002
# dailyCommission：2.5800659523809526
# totalSlippage：0.134
# dailySlippage：0.0015952380952380953
# totalTurnover：433451.07999999996
# dailyTurnover：5160.1319047619045
# totalTradeCount：67
# dailyTradeCount：0.7976190476190477
# totalReturn：0.2944510460000105
# annualizedReturn：0.8412887028571728
# dailyReturn：0.0033704867001150248
# returnStd：0.014000755689692331
# sharpeRatio：3.729466936636745
# ------------------------------
# 参数：["{'fastPeriod': 18, 'slowPeriod': 40, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.71997491643264
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：42
# lossDays：41
# endBalance：1001926.63616
# maxDrawdown：-1054.304220000049
# maxDdPercent：-0.10579714854766871
# totalNetPnl：1926.6361600000034
# dailyNetPnl：22.936144761904803
# totalCommission：377.93584000000004
# dailyCommission：4.499236190476191
# totalSlippage：0.23800000000000004
# dailySlippage：0.002833333333333334
# totalTurnover：755871.6799999999
# dailyTurnover：8998.47238095238
# totalTradeCount：119
# dailyTradeCount：1.4166666666666667
# totalReturn：0.19266361599998838
# annualizedReturn：0.5504674742856811
# dailyReturn：0.008950591998688329
# returnStd：0.037274975803181565
# sharpeRatio：3.71997491643264
# ------------------------------
# 参数：["{'fastPeriod': 24, 'slowPeriod': 55, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.7133100102863126
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：48
# lossDays：34
# endBalance：1002946.92985
# maxDrawdown：-393.87464000005275
# maxDdPercent：-0.0393305538778999
# totalNetPnl：2946.9298499999995
# dailyNetPnl：35.08249821428571
# totalCommission：230.15814999999998
# dailyCommission：2.739977976190476
# totalSlippage：0.14200000000000002
# dailySlippage：0.0016904761904761906
# totalTurnover：460316.3
# dailyTurnover：5479.955952380952
# totalTradeCount：71
# dailyTradeCount：0.8452380952380952
# totalReturn：0.2946929850000002
# annualizedReturn：0.8419799571428577
# dailyReturn：0.003373358466884384
# returnStd：0.01407365517755264
# sharpeRatio：3.7133100102863126
# ------------------------------
# 参数：["{'fastPeriod': 18, 'slowPeriod': 55, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.6904697416237155
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：51
# lossDays：31
# endBalance：1002973.51917
# maxDrawdown：-402.9000000000233
# maxDdPercent：-0.04027709759468452
# totalNetPnl：2973.5191699999996
# dailyNetPnl：35.39903773809523
# totalCommission：216.17683
# dailyCommission：2.5735336904761903
# totalSlippage：0.134
# dailySlippage：0.0015952380952380953
# totalTurnover：432353.66000000003
# dailyTurnover：5147.067380952381
# totalTradeCount：67
# dailyTradeCount：0.7976190476190477
# totalReturn：0.2973519169999994
# annualizedReturn：0.8495769057142841
# dailyReturn：0.003404918993023981
# returnStd：0.014293242300764853
# sharpeRatio：3.6904697416237155
# ------------------------------
# 参数：["{'fastPeriod': 33, 'slowPeriod': 45, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.6799169465459127
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：46
# lossDays：37
# endBalance：1001493.12005
# maxDrawdown：-873.3494300000602
# maxDdPercent：-0.08761432559715705
# totalNetPnl：1493.1200500000016
# dailyNetPnl：17.775238690476208
# totalCommission：379.83194999999995
# dailyCommission：4.521808928571428
# totalSlippage：0.23800000000000002
# dailySlippage：0.0028333333333333335
# totalTurnover：759663.9
# dailyTurnover：9043.617857142857
# totalTradeCount：119
# dailyTradeCount：1.4166666666666667
# totalReturn：0.14931200500001296
# annualizedReturn：0.42660572857146556
# dailyReturn：0.008435382329223595
# returnStd：0.035511774591152664
# sharpeRatio：3.6799169465459127
# ------------------------------
# 参数：["{'fastPeriod': 30, 'slowPeriod': 40, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.6425674453940045
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：47
# lossDays：36
# endBalance：1001631.20066
# maxDrawdown：-877.8513800000073
# maxDdPercent：-0.08806907160978593
# totalNetPnl：1631.200659999997
# dailyNetPnl：19.41905547619044
# totalCommission：393.76333999999997
# dailyCommission：4.687658809523809
# totalSlippage：0.24600000000000005
# dailySlippage：0.0029285714285714293
# totalTurnover：787526.6799999998
# dailyTurnover：9375.317619047617
# totalTradeCount：123
# dailyTradeCount：1.4642857142857142
# totalReturn：0.16312006599998874
# annualizedReturn：0.4660573314285393
# dailyReturn：0.00859950761803716
# returnStd：0.03657392791159606
# sharpeRatio：3.6425674453940045
# ------------------------------
# 参数：["{'fastPeriod': 33, 'slowPeriod': 40, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.5943813185318425
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：48
# lossDays：35
# endBalance：1001396.01521
# maxDrawdown：-962.1031199999852
# maxDdPercent：-0.09653586124022241
# totalNetPnl：1396.0152099999964
# dailyNetPnl：16.61922869047615
# totalCommission：428.78479
# dailyCommission：5.104580833333333
# totalSlippage：0.27
# dailySlippage：0.0032142857142857147
# totalTurnover：857569.58
# dailyTurnover：10209.161666666667
# totalTradeCount：135
# dailyTradeCount：1.6071428571428572
# totalReturn：0.1396015209999879
# annualizedReturn：0.398861488571394
# dailyReturn：0.00831994808171051
# returnStd：0.03585932321163625
# sharpeRatio：3.5943813185318425
# ------------------------------
# 参数：["{'fastPeriod': 21, 'slowPeriod': 75, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.5683869106364936
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：46
# lossDays：36
# endBalance：1002914.99457
# maxDrawdown：-364.22970999998506
# maxDdPercent：-0.036381616471325755
# totalNetPnl：2914.9945700000026
# dailyNetPnl：34.70231630952384
# totalCommission：177.68543000000003
# dailyCommission：2.1153027380952385
# totalSlippage：0.11
# dailySlippage：0.0013095238095238095
# totalTurnover：355370.86
# dailyTurnover：4230.605476190476
# totalTradeCount：55
# dailyTradeCount：0.6547619047619048
# totalReturn：0.2914994569999996
# annualizedReturn：0.8328555914285701
# dailyReturn：0.003335451380641936
# returnStd：0.014480658037170687
# sharpeRatio：3.5683869106364936
# ------------------------------
# 参数：["{'fastPeriod': 15, 'slowPeriod': 55, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.5672398855844705
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：50
# lossDays：32
# endBalance：1002955.39721
# maxDrawdown：-402.9000000000233
# maxDdPercent：-0.04027709759468452
# totalNetPnl：2955.3972099999987
# dailyNetPnl：35.1833001190476
# totalCommission：212.41879
# dailyCommission：2.528795119047619
# totalSlippage：0.134
# dailySlippage：0.0015952380952380953
# totalTurnover：424837.58
# dailyTurnover：5057.590238095238
# totalTradeCount：67
# dailyTradeCount：0.7976190476190477
# totalReturn：0.29553972100000436
# annualizedReturn：0.8443992028571554
# dailyReturn：0.0033834089966050264
# returnStd：0.014693586209566192
# sharpeRatio：3.5672398855844705
# ------------------------------
# 参数：["{'fastPeriod': 27, 'slowPeriod': 55, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.527383830540028
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：49
# lossDays：33
# endBalance：1002855.55688
# maxDrawdown：-471.2901500000153
# maxDdPercent：-0.04705741956899589
# totalNetPnl：2855.556879999999
# dailyNetPnl：33.99472476190475
# totalCommission：217.27912
# dailyCommission：2.5866561904761904
# totalSlippage：0.134
# dailySlippage：0.0015952380952380953
# totalTurnover：434558.24
# dailyTurnover：5173.31238095238
# totalTradeCount：67
# dailyTradeCount：0.7976190476190477
# totalReturn：0.2855556879999943
# annualizedReturn：0.815873394285698
# dailyReturn：0.003264895798169153
# returnStd：0.014339110979567905
# sharpeRatio：3.527383830540028
# ------------------------------
# 参数：["{'fastPeriod': 18, 'slowPeriod': 75, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.524185543492182
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：47
# lossDays：35
# endBalance：1002897.63779
# maxDrawdown：-365.26584999996703
# maxDdPercent：-0.036463892193311316
# totalNetPnl：2897.6377899999993
# dailyNetPnl：34.49568797619047
# totalCommission：190.87421
# dailyCommission：2.272312023809524
# totalSlippage：0.11800000000000001
# dailySlippage：0.0014047619047619047
# totalTurnover：381748.42000000004
# dailyTurnover：4544.624047619048
# totalTradeCount：59
# dailyTradeCount：0.7023809523809523
# totalReturn：0.2897637789999852
# annualizedReturn：0.827896511428529
# dailyReturn：0.0033148484260085774
# returnStd：0.014571710360529228
# sharpeRatio：3.524185543492182
# ------------------------------
# 参数：["{'fastPeriod': 21, 'slowPeriod': 80, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.5013583866171616
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：47
# lossDays：35
# endBalance：1002863.30013
# maxDrawdown：-403.0754799999995
# maxDdPercent：-0.04025870106603667
# totalNetPnl：2863.3001300000024
# dailyNetPnl：34.08690630952384
# totalCommission：177.69987000000003
# dailyCommission：2.1154746428571434
# totalSlippage：0.11
# dailySlippage：0.0013095238095238095
# totalTurnover：355399.74
# dailyTurnover：4230.949285714286
# totalTradeCount：55
# dailyTradeCount：0.6547619047619048
# totalReturn：0.2863300130000024
# annualizedReturn：0.8180857514285783
# dailyReturn：0.003274087669433289
# returnStd：0.01448636285414866
# sharpeRatio：3.5013583866171616
# ------------------------------
# 参数：["{'fastPeriod': 18, 'slowPeriod': 70, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.4884160179193624
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：49
# lossDays：33
# endBalance：1002819.10869
# maxDrawdown：-308.7471000000369
# maxDdPercent：-0.0308648227321335
# totalNetPnl：2819.1086899999987
# dailyNetPnl：33.560817738095224
# totalCommission：214.78731
# dailyCommission：2.5569917857142856
# totalSlippage：0.134
# dailySlippage：0.0015952380952380953
# totalTurnover：429574.62
# dailyTurnover：5113.983571428571
# totalTradeCount：67
# dailyTradeCount：0.7976190476190477
# totalReturn：0.2819108690000016
# annualizedReturn：0.8054596257142904
# dailyReturn：0.003221627861318833
# returnStd：0.014307136523249483
# sharpeRatio：3.4884160179193624
# ------------------------------
# 参数：["{'fastPeriod': 24, 'slowPeriod': 60, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.4683320696332096
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：49
# lossDays：33
# endBalance：1002809.43961
# maxDrawdown：-387.87000000011176
# maxDdPercent：-0.03877457891301535
# totalNetPnl：2809.4396099999985
# dailyNetPnl：33.445709642857125
# totalCommission：216.61639000000002
# dailyCommission：2.5787665476190478
# totalSlippage：0.134
# dailySlippage：0.0015952380952380953
# totalTurnover：433232.77999999997
# dailyTurnover：5157.533095238095
# totalTradeCount：67
# dailyTradeCount：0.7976190476190477
# totalReturn：0.28094396100000196
# annualizedReturn：0.802697031428577
# dailyReturn：0.00321014935545874
# returnStd：0.014338713529059516
# sharpeRatio：3.4683320696332096
# ------------------------------
# 参数：["{'fastPeriod': 21, 'slowPeriod': 70, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.4647461968102298
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：47
# lossDays：35
# endBalance：1002792.52914
# maxDrawdown：-308.7471000000369
# maxDdPercent：-0.0308648227321335
# totalNetPnl：2792.529139999999
# dailyNetPnl：33.24439452380951
# totalCommission：203.55486000000002
# dailyCommission：2.423272142857143
# totalSlippage：0.126
# dailySlippage：0.0015
# totalTurnover：407109.72
# dailyTurnover：4846.544285714285
# totalTradeCount：63
# dailyTradeCount：0.75
# totalReturn：0.2792529139999944
# annualizedReturn：0.7978654685714126
# dailyReturn：0.003190074074101884
# returnStd：0.014263790835287383
# sharpeRatio：3.4647461968102298
# ------------------------------
# 参数：["{'fastPeriod': 21, 'slowPeriod': 65, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.450721789846789
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：48
# lossDays：34
# endBalance：1002795.28118
# maxDrawdown：-315.2261700000381
# maxDdPercent：-0.03150268953616535
# totalNetPnl：2795.28118
# dailyNetPnl：33.2771569047619
# totalCommission：203.52282
# dailyCommission：2.4228907142857143
# totalSlippage：0.126
# dailySlippage：0.0015
# totalTurnover：407045.64
# dailyTurnover：4845.7814285714285
# totalTradeCount：63
# dailyTradeCount：0.75
# totalReturn：0.2795281180000053
# annualizedReturn：0.7986517657143009
# dailyReturn：0.0031933411842018024
# returnStd：0.014336429278723136
# sharpeRatio：3.450721789846789
# ------------------------------
# 参数：["{'fastPeriod': 18, 'slowPeriod': 80, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.4350235195203966
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：47
# lossDays：35
# endBalance：1002784.2774
# maxDrawdown：-475.78523999999743
# maxDdPercent：-0.04751652691936422
# totalNetPnl：2784.2774
# dailyNetPnl：33.14615952380952
# totalCommission：190.8546
# dailyCommission：2.2720785714285716
# totalSlippage：0.11800000000000001
# dailySlippage：0.0014047619047619047
# totalTurnover：381709.19999999995
# dailyTurnover：4544.157142857142
# totalTradeCount：59
# dailyTradeCount：0.7023809523809523
# totalReturn：0.2784277399999979
# annualizedReturn：0.7955078285714225
# dailyReturn：0.0031802778898148447
# returnStd：0.01434303227744339
# sharpeRatio：3.4350235195203966
# ------------------------------
# 参数：["{'fastPeriod': 18, 'slowPeriod': 85, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.4108051361439493
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：48
# lossDays：34
# endBalance：1002733.95341
# maxDrawdown：-471.07111000001896
# maxDdPercent：-0.047056908309608216
# totalNetPnl：2733.9534100000014
# dailyNetPnl：32.54706440476192
# totalCommission：191.23859
# dailyCommission：2.2766498809523807
# totalSlippage：0.11800000000000001
# dailySlippage：0.0014047619047619047
# totalTurnover：382477.18
# dailyTurnover：4553.299761904762
# totalTradeCount：59
# dailyTradeCount：0.7023809523809523
# totalReturn：0.2733953409999934
# annualizedReturn：0.781129545714267
# dailyReturn：0.0031205332203343957
# returnStd：0.014173513538572375
# sharpeRatio：3.4108051361439493
# ------------------------------
# 参数：["{'fastPeriod': 18, 'slowPeriod': 65, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.316588493881783
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：48
# lossDays：34
# endBalance：1002685.55162
# maxDrawdown：-308.7471000000369
# maxDdPercent：-0.0308648227321335
# totalNetPnl：2685.5516199999993
# dailyNetPnl：31.970852619047612
# totalCommission：203.45238
# dailyCommission：2.422052142857143
# totalSlippage：0.126
# dailySlippage：0.0015
# totalTurnover：406904.76
# dailyTurnover：4844.104285714286
# totalTradeCount：63
# dailyTradeCount：0.75
# totalReturn：0.26855516199999485
# annualizedReturn：0.7673004628571282
# dailyReturn：0.0030630677589312447
# returnStd：0.01430772667821773
# sharpeRatio：3.316588493881783
# ------------------------------
# 参数：["{'fastPeriod': 21, 'slowPeriod': 90, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.250251946871682
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：47
# lossDays：35
# endBalance：1002614.88691
# maxDrawdown：-492.4853600000497
# maxDdPercent：-0.04919317727603991
# totalNetPnl：2614.886909999997
# dailyNetPnl：31.129606071428537
# totalCommission：165.20109
# dailyCommission：1.9666796428571427
# totalSlippage：0.10200000000000001
# dailySlippage：0.0012142857142857144
# totalTurnover：330402.18000000005
# dailyTurnover：3933.359285714286
# totalTradeCount：51
# dailyTradeCount：0.6071428571428571
# totalReturn：0.2614886910000003
# annualizedReturn：0.7471105457142865
# dailyReturn：0.002979165463614547
# returnStd：0.014199832400415405
# sharpeRatio：3.250251946871682
# ------------------------------
# 参数：["{'fastPeriod': 15, 'slowPeriod': 75, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.2443907496758886
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：48
# lossDays：34
# endBalance：1002694.117
# maxDrawdown：-402.9000000000233
# maxDdPercent：-0.04027709759468452
# totalNetPnl：2694.117
# dailyNetPnl：32.07282142857143
# totalCommission：216.99900000000002
# dailyCommission：2.5833214285714288
# totalSlippage：0.134
# dailySlippage：0.0015952380952380953
# totalTurnover：433998.0
# dailyTurnover：5166.642857142857
# totalTradeCount：67
# dailyTradeCount：0.7976190476190477
# totalReturn：0.2694116999999885
# annualizedReturn：0.7697477142856815
# dailyReturn：0.003073237285542535
# returnStd：0.014674677305178463
# sharpeRatio：3.2443907496758886
# ------------------------------
# 参数：["{'fastPeriod': 30, 'slowPeriod': 55, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.2098802635538073
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：47
# lossDays：35
# endBalance：1002559.77769
# maxDrawdown：-464.39876000001095
# maxDdPercent：-0.04637499158155705
# totalNetPnl：2559.77769
# dailyNetPnl：30.473543928571427
# totalCommission：225.51031
# dailyCommission：2.6846465476190478
# totalSlippage：0.14200000000000002
# dailySlippage：0.0016904761904761906
# totalTurnover：451020.62
# dailyTurnover：5369.293095238095
# totalTradeCount：71
# dailyTradeCount：0.8452380952380952
# totalReturn：0.25597776899999314
# annualizedReturn：0.7313650542856946
# dailyReturn：0.0029137285563355215
# returnStd：0.014062608256374653
# sharpeRatio：3.2098802635538073
# ------------------------------
# 参数：["{'fastPeriod': 24, 'slowPeriod': 70, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.1759837668648636
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：45
# lossDays：37
# endBalance：1002571.6012800001
# maxDrawdown：-506.51926999993157
# maxDdPercent：-0.05059405768276412
# totalNetPnl：2571.6012800000026
# dailyNetPnl：30.614300952380983
# totalCommission：190.73072000000002
# dailyCommission：2.2706038095238097
# totalSlippage：0.11800000000000001
# dailySlippage：0.0014047619047619047
# totalTurnover：381461.44
# dailyTurnover：4541.207619047619
# totalTradeCount：59
# dailyTradeCount：0.7023809523809523
# totalReturn：0.2571601280000113
# annualizedReturn：0.7347432228571752
# dailyReturn：0.002927768237253894
# returnStd：0.01428117831424905
# sharpeRatio：3.1759837668648636
# ------------------------------
# 参数：["{'fastPeriod': 24, 'slowPeriod': 80, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.1419717724425924
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：47
# lossDays：35
# endBalance：1002587.35521
# maxDrawdown：-437.46596000005957
# maxDdPercent：-0.0436997571887489
# totalNetPnl：2587.355209999997
# dailyNetPnl：30.8018477380952
# totalCommission：190.55679
# dailyCommission：2.268533214285714
# totalSlippage：0.11800000000000001
# dailySlippage：0.0014047619047619047
# totalTurnover：381113.57999999996
# dailyTurnover：4537.066428571428
# totalTradeCount：59
# dailyTradeCount：0.7023809523809523
# totalReturn：0.2587355209999975
# annualizedReturn：0.7392443457142787
# dailyReturn：0.0029464746630083367
# returnStd：0.014528007412341453
# sharpeRatio：3.1419717724425924
# ------------------------------
# 参数：["{'fastPeriod': 15, 'slowPeriod': 70, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.1338270570781823
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：50
# lossDays：32
# endBalance：1002613.88818
# maxDrawdown：-402.9000000000233
# maxDdPercent：-0.04027709759468452
# totalNetPnl：2613.888179999998
# dailyNetPnl：31.117716428571406
# totalCommission：190.84382
# dailyCommission：2.271950238095238
# totalSlippage：0.11800000000000001
# dailySlippage：0.0014047619047619047
# totalTurnover：381687.64
# dailyTurnover：4543.900476190476
# totalTradeCount：59
# dailyTradeCount：0.7023809523809523
# totalReturn：0.2613888179999968
# annualizedReturn：0.7468251942857052
# dailyReturn：0.0029779795996361037
# returnStd：0.01472150847467563
# sharpeRatio：3.1338270570781823
# ------------------------------
# 参数：["{'fastPeriod': 18, 'slowPeriod': 100, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.1189977711756645
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：44
# lossDays：38
# endBalance：1002629.88655
# maxDrawdown：-543.0265500000678
# maxDdPercent：-0.05424497578890437
# totalNetPnl：2629.88655
# dailyNetPnl：31.308173214285716
# totalCommission：127.62545
# dailyCommission：1.5193505952380952
# totalSlippage：0.07800000000000001
# dailySlippage：0.0009285714285714288
# totalTurnover：255250.90000000002
# dailyTurnover：3038.7011904761907
# totalTradeCount：39
# dailyTradeCount：0.4642857142857143
# totalReturn：0.2629886550000071
# annualizedReturn：0.7513961571428776
# dailyReturn：0.0029969754731663466
# returnStd：0.014885853659574962
# sharpeRatio：3.1189977711756645
# ------------------------------
# 参数：["{'fastPeriod': 24, 'slowPeriod': 50, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.1161746483257273
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：47
# lossDays：36
# endBalance：1002542.72272
# maxDrawdown：-348.9548099999083
# maxDdPercent：-0.034853915497764204
# totalNetPnl：2542.722719999993
# dailyNetPnl：30.270508571428486
# totalCommission：260.96128
# dailyCommission：3.1066819047619045
# totalSlippage：0.16600000000000004
# dailySlippage：0.0019761904761904764
# totalTurnover：521922.56
# dailyTurnover：6213.363809523809
# totalTradeCount：83
# dailyTradeCount：0.9880952380952381
# totalReturn：0.25427227199998903
# annualizedReturn：0.7264922057142543
# dailyReturn：0.002893476688203833
# returnStd：0.014384799686466682
# sharpeRatio：3.1161746483257273
# ------------------------------
# 参数：["{'fastPeriod': 15, 'slowPeriod': 50, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.0935886331686047
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：49
# lossDays：33
# endBalance：1002622.10377
# maxDrawdown：-394.818740000017
# maxDdPercent：-0.039444189670047855
# totalNetPnl：2622.1037700000015
# dailyNetPnl：31.21552107142859
# totalCommission：225.50423
# dailyCommission：2.6845741666666667
# totalSlippage：0.14200000000000002
# dailySlippage：0.0016904761904761906
# totalTurnover：451008.46
# dailyTurnover：5369.1483333333335
# totalTradeCount：71
# dailyTradeCount：0.8452380952380952
# totalReturn：0.26221037700000505
# annualizedReturn：0.7491725057143
# dailyReturn：0.0029877345255655656
# returnStd：0.014961841967401222
# sharpeRatio：3.0935886331686047
# ------------------------------
# 参数：["{'fastPeriod': 33, 'slowPeriod': 80, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.090179142646781
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：44
# lossDays：38
# endBalance：1002570.67201
# maxDrawdown：-499.2560499999672
# maxDdPercent：-0.04988185531370069
# totalNetPnl：2570.6720099999966
# dailyNetPnl：30.603238214285675
# totalCommission：186.40399
# dailyCommission：2.219095119047619
# totalSlippage：0.114
# dailySlippage：0.0013571428571428571
# totalTurnover：372807.98
# dailyTurnover：4438.190238095238
# totalTradeCount：57
# dailyTradeCount：0.6785714285714286
# totalReturn：0.25706720100000524
# annualizedReturn：0.734477717142872
# dailyReturn：0.0029516746948082023
# returnStd：0.014797571802419902
# sharpeRatio：3.090179142646781
# ------------------------------
# 参数：["{'fastPeriod': 21, 'slowPeriod': 40, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.0869491409342116
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：45
# lossDays：37
# endBalance：1002605.80791
# maxDrawdown：-402.9000000000233
# maxDdPercent：-0.04027734887022234
# totalNetPnl：2605.8079099999977
# dailyNetPnl：31.02152273809521
# totalCommission：353.20009
# dailyCommission：4.204762976190476
# totalSlippage：0.22200000000000003
# dailySlippage：0.0026428571428571434
# totalTurnover：706400.1799999999
# dailyTurnover：8409.525952380951
# totalTradeCount：111
# dailyTradeCount：1.3214285714285714
# totalReturn：0.260580790999998
# annualizedReturn：0.7445165457142799
# dailyReturn：0.0029683852703304716
# returnStd：0.014896917561315053
# sharpeRatio：3.0869491409342116
# ------------------------------
# 参数：["{'fastPeriod': 15, 'slowPeriod': 65, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.079650843870491
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：49
# lossDays：33
# endBalance：1002556.90899
# maxDrawdown：-423.2363700000569
# maxDdPercent：-0.0423008617511524
# totalNetPnl：2556.9089899999985
# dailyNetPnl：30.439392738095222
# totalCommission：203.31501
# dailyCommission：2.4204167857142855
# totalSlippage：0.126
# dailySlippage：0.0015
# totalTurnover：406630.02
# dailyTurnover：4840.833571428571
# totalTradeCount：63
# dailyTradeCount：0.75
# totalReturn：0.255690898999994
# annualizedReturn：0.7305454257142685
# dailyReturn：0.002910322152040377
# returnStd：0.014640139156534747
# sharpeRatio：3.079650843870491
# ------------------------------
# 参数：["{'fastPeriod': 15, 'slowPeriod': 100, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.0786340336085
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：46
# lossDays：36
# endBalance：1002590.26448
# maxDrawdown：-618.9605600000359
# maxDdPercent：-0.0618214028688603
# totalNetPnl：2590.2644800000025
# dailyNetPnl：30.836481904761936
# totalCommission：140.69952
# dailyCommission：1.6749942857142859
# totalSlippage：0.086
# dailySlippage：0.0010238095238095236
# totalTurnover：281399.04000000004
# dailyTurnover：3349.988571428572
# totalTradeCount：43
# dailyTradeCount：0.5119047619047619
# totalReturn：0.2590264479999993
# annualizedReturn：0.7400755657142837
# dailyReturn：0.002949929136699564
# returnStd：0.014844280020562286
# sharpeRatio：3.0786340336085
# ------------------------------
# 参数：["{'fastPeriod': 27, 'slowPeriod': 80, 'symbolList': ['BTCUSDT:binance']}"]，目标：3.0357252009304982
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：45
# lossDays：37
# endBalance：1002385.22704
# maxDrawdown：-453.31535000004806
# maxDdPercent：-0.04528701607934325
# totalNetPnl：2385.2270399999966
# dailyNetPnl：28.39555999999996
# totalCommission：190.50496
# dailyCommission：2.2679161904761904
# totalSlippage：0.11800000000000001
# dailySlippage：0.0014047619047619047
# totalTurnover：381009.92000000004
# dailyTurnover：4535.832380952382
# totalTradeCount：59
# dailyTradeCount：0.7023809523809523
# totalReturn：0.2385227039999993
# annualizedReturn：0.681493439999998
# dailyReturn：0.0027064426777784994
# returnStd：0.013811536584784725
# sharpeRatio：3.0357252009304982
# ------------------------------
# 参数：["{'fastPeriod': 27, 'slowPeriod': 60, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.982052782937428
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：46
# lossDays：36
# endBalance：1002351.7797
# maxDrawdown：-421.8684099999955
# maxDdPercent：-0.04214216191028462
# totalNetPnl：2351.779700000003
# dailyNetPnl：27.997377380952415
# totalCommission：203.3843
# dailyCommission：2.4212416666666665
# totalSlippage：0.126
# dailySlippage：0.0015
# totalTurnover：406768.6
# dailyTurnover：4842.483333333333
# totalTradeCount：63
# dailyTradeCount：0.75
# totalReturn：0.23517796999998897
# annualizedReturn：0.6719370571428256
# dailyReturn：0.0026667185027116702
# returnStd：0.013853753909549349
# sharpeRatio：2.982052782937428
# ------------------------------
# 参数：["{'fastPeriod': 21, 'slowPeriod': 85, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.979107117325508
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：45
# lossDays：37
# endBalance：1002471.73697
# maxDrawdown：-776.4793700000737
# maxDdPercent：-0.07756073360188312
# totalNetPnl：2471.736969999998
# dailyNetPnl：29.425440119047597
# totalCommission：178.50303000000002
# dailyCommission：2.1250360714285716
# totalSlippage：0.11000000000000001
# dailySlippage：0.0013095238095238097
# totalTurnover：357006.06
# dailyTurnover：4250.072142857143
# totalTradeCount：55
# dailyTradeCount：0.6547619047619048
# totalReturn：0.2471736970000027
# annualizedReturn：0.7062105628571506
# dailyReturn：0.002809181191115464
# returnStd：0.014608285692575895
# sharpeRatio：2.979107117325508
# ------------------------------
# 参数：["{'fastPeriod': 33, 'slowPeriod': 85, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.968074941010068
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：45
# lossDays：37
# endBalance：1002412.82144
# maxDrawdown：-502.1496699999552
# maxDdPercent：-0.05016869578777189
# totalNetPnl：2412.821439999997
# dailyNetPnl：28.724064761904724
# totalCommission：184.51456000000002
# dailyCommission：2.1966019047619048
# totalSlippage：0.114
# dailySlippage：0.0013571428571428571
# totalTurnover：369029.12000000005
# dailyTurnover：4393.20380952381
# totalTradeCount：57
# dailyTradeCount：0.6785714285714286
# totalReturn：0.24128214399998793
# annualizedReturn：0.6893775542856798
# dailyReturn：0.0027482417625010603
# returnStd：0.014344509204199666
# sharpeRatio：2.968074941010068
# ------------------------------
# 参数：["{'fastPeriod': 21, 'slowPeriod': 100, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.967453537642421
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：44
# lossDays：38
# endBalance：1002502.35993
# maxDrawdown：-463.3467299999902
# maxDdPercent：-0.04628679496130348
# totalNetPnl：2502.3599300000005
# dailyNetPnl：29.78999916666667
# totalCommission：140.82407
# dailyCommission：1.676477023809524
# totalSlippage：0.08600000000000001
# dailySlippage：0.0010238095238095238
# totalTurnover：281648.14
# dailyTurnover：3352.9540476190477
# totalTradeCount：43
# dailyTradeCount：0.5119047619047619
# totalReturn：0.2502359930000031
# annualizedReturn：0.7149599800000088
# dailyReturn：0.002845546653215284
# returnStd：0.014855504436999276
# sharpeRatio：2.967453537642421
# ------------------------------
# 参数：["{'fastPeriod': 18, 'slowPeriod': 95, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.965003679492184
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：47
# lossDays：35
# endBalance：1002437.49379
# maxDrawdown：-608.1939499999862
# maxDdPercent：-0.0607535640255112
# totalNetPnl：2437.493790000002
# dailyNetPnl：29.017783214285735
# totalCommission：164.99421
# dailyCommission：1.9642167857142858
# totalSlippage：0.10200000000000001
# dailySlippage：0.0012142857142857144
# totalTurnover：329988.42
# dailyTurnover：3928.433571428571
# totalTradeCount：51
# dailyTradeCount：0.6071428571428571
# totalReturn：0.24374937900000226
# annualizedReturn：0.6964267971428636
# dailyReturn：0.002768515319708681
# returnStd：0.014465295677188841
# sharpeRatio：2.965003679492184
# ------------------------------
# 参数：["{'fastPeriod': 30, 'slowPeriod': 80, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.9456588639684242
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：45
# lossDays：37
# endBalance：1002284.20603
# maxDrawdown：-439.1731599998893
# maxDdPercent：-0.043874819188397904
# totalNetPnl：2284.2060299999976
# dailyNetPnl：27.192928928571398
# totalCommission：208.89397000000002
# dailyCommission：2.4868329761904766
# totalSlippage：0.13
# dailySlippage：0.0015476190476190477
# totalTurnover：417787.93999999994
# dailyTurnover：4973.665952380952
# totalTradeCount：65
# dailyTradeCount：0.7738095238095238
# totalReturn：0.22842060299999023
# annualizedReturn：0.6526302942856863
# dailyReturn：0.0026114695910586135
# returnStd：0.013734351060151168
# sharpeRatio：2.9456588639684242
# ------------------------------
# 参数：["{'fastPeriod': 18, 'slowPeriod': 90, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.9379554326275747
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：47
# lossDays：35
# endBalance：1002401.17703
# maxDrawdown：-565.5335000000196
# maxDdPercent：-0.056501144650939104
# totalNetPnl：2401.1770300000007
# dailyNetPnl：28.585440833333344
# totalCommission：178.18297
# dailyCommission：2.1212258333333334
# totalSlippage：0.11
# dailySlippage：0.0013095238095238095
# totalTurnover：356365.94
# dailyTurnover：4242.451666666667
# totalTradeCount：55
# dailyTradeCount：0.6547619047619048
# totalReturn：0.240117703000009
# annualizedReturn：0.6860505800000257
# dailyReturn：0.002725385427285044
# returnStd：0.014371044917357528
# sharpeRatio：2.9379554326275747
# ------------------------------
# 参数：["{'fastPeriod': 24, 'slowPeriod': 75, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.924738877881142
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：48
# lossDays：34
# endBalance：1002427.36453
# maxDrawdown：-499.4478100000415
# maxDdPercent：-0.04989172772579207
# totalNetPnl：2427.364529999998
# dailyNetPnl：28.89719678571426
# totalCommission：190.58747
# dailyCommission：2.2688984523809523
# totalSlippage：0.11800000000000001
# dailySlippage：0.0014047619047619047
# totalTurnover：381174.94
# dailyTurnover：4537.796904761904
# totalTradeCount：59
# dailyTradeCount：0.7023809523809523
# totalReturn：0.24273645299999203
# annualizedReturn：0.69353272285712
# dailyReturn：0.002756485937471269
# returnStd：0.014600721056664556
# sharpeRatio：2.924738877881142
# ------------------------------
# 参数：["{'fastPeriod': 30, 'slowPeriod': 60, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.919579847922548
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：46
# lossDays：36
# endBalance：1002355.27175
# maxDrawdown：-389.8078800000949
# maxDdPercent：-0.03894007951091429
# totalNetPnl：2355.271749999997
# dailyNetPnl：28.038949404761873
# totalCommission：190.32025000000002
# dailyCommission：2.2657172619047623
# totalSlippage：0.11800000000000001
# dailySlippage：0.0014047619047619047
# totalTurnover：380640.5
# dailyTurnover：4531.434523809524
# totalTradeCount：59
# dailyTradeCount：0.7023809523809523
# totalReturn：0.23552717499999432
# annualizedReturn：0.6729347857142695
# dailyReturn：0.002670865943982512
# returnStd：0.014172202659033066
# sharpeRatio：2.919579847922548
# ------------------------------
# 参数：["{'fastPeriod': 18, 'slowPeriod': 60, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.8926117544202143
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：49
# lossDays：33
# endBalance：1002453.31715
# maxDrawdown：-499.69573999999557
# maxDdPercent：-0.049936076484899124
# totalNetPnl：2453.3171499999994
# dailyNetPnl：29.20615654761904
# totalCommission：215.85885000000002
# dailyCommission：2.5697482142857146
# totalSlippage：0.134
# dailySlippage：0.0015952380952380953
# totalTurnover：431717.7
# dailyTurnover：5139.496428571429
# totalTradeCount：67
# dailyTradeCount：0.7976190476190477
# totalReturn：0.24533171500000783
# annualizedReturn：0.7009477571428796
# dailyReturn：0.002787306700496608
# returnStd：0.014927952104598236
# sharpeRatio：2.8926117544202143
# ------------------------------
# 参数：["{'fastPeriod': 27, 'slowPeriod': 50, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.88913578267928
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：47
# lossDays：35
# endBalance：1002376.14214
# maxDrawdown：-469.57341000007
# maxDdPercent：-0.046906991561561265
# totalNetPnl：2376.1421399999963
# dailyNetPnl：28.287406428571384
# totalCommission：290.68586000000005
# dailyCommission：3.460545952380953
# totalSlippage：0.18200000000000002
# dailySlippage：0.002166666666666667
# totalTurnover：581371.72
# dailyTurnover：6921.0919047619045
# totalTradeCount：91
# dailyTradeCount：1.0833333333333333
# totalReturn：0.2376142139999926
# annualizedReturn：0.6788977542856931
# dailyReturn：0.002695653007436133
# returnStd：0.014454452805637537
# sharpeRatio：2.88913578267928
# ------------------------------
# 参数：["{'fastPeriod': 15, 'slowPeriod': 90, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.867627434343833
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：46
# lossDays：36
# endBalance：1002316.01897
# maxDrawdown：-623.0628400000278
# maxDdPercent：-0.0622459199540996
# totalNetPnl：2316.018970000002
# dailyNetPnl：27.571654404761926
# totalCommission：204.20503
# dailyCommission：2.431012261904762
# totalSlippage：0.126
# dailySlippage：0.0015
# totalTurnover：408410.05999999994
# dailyTurnover：4862.024523809523
# totalTradeCount：63
# dailyTradeCount：0.75
# totalReturn：0.231601897
# annualizedReturn：0.6617197057142857
# dailyReturn：0.002624245333190548
# returnStd：0.014177097554704017
# sharpeRatio：2.867627434343833
# ------------------------------
# 参数：["{'fastPeriod': 27, 'slowPeriod': 70, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.8621786448892315
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：47
# lossDays：35
# endBalance：1002374.27811
# maxDrawdown：-436.6513300000224
# maxDdPercent：-0.04361886731147005
# totalNetPnl：2374.2781099999975
# dailyNetPnl：28.265215595238065
# totalCommission：203.30589
# dailyCommission：2.4203082142857144
# totalSlippage：0.126
# dailySlippage：0.0015
# totalTurnover：406611.78
# dailyTurnover：4840.6164285714285
# totalTradeCount：63
# dailyTradeCount：0.75
# totalReturn：0.23742781100000165
# annualizedReturn：0.6783651742857191
# dailyReturn：0.0026934391824038444
# returnStd：0.01457860796508923
# sharpeRatio：2.8621786448892315
# ------------------------------
# 参数：["{'fastPeriod': 15, 'slowPeriod': 95, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.860250234541673
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：46
# lossDays：36
# endBalance：1002417.02342
# maxDrawdown：-645.7839699999895
# maxDdPercent：-0.06450685104912142
# totalNetPnl：2417.023420000001
# dailyNetPnl：28.774088333333346
# totalCommission：167.08458000000002
# dailyCommission：1.9891021428571432
# totalSlippage：0.10200000000000001
# dailySlippage：0.0012142857142857144
# totalTurnover：334169.16000000003
# dailyTurnover：3978.204285714286
# totalTradeCount：51
# dailyTradeCount：0.6071428571428571
# totalReturn：0.2417023420000053
# annualizedReturn：0.6905781200000152
# dailyReturn：0.002744204839436445
# returnStd：0.01486339833258991
# sharpeRatio：2.860250234541673
# ------------------------------
# 参数：["{'fastPeriod': 15, 'slowPeriod': 80, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.8276696465234363
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：46
# lossDays：36
# endBalance：1002415.75935
# maxDrawdown：-494.2322100000456
# maxDdPercent：-0.04937411175517815
# totalNetPnl：2415.7593500000003
# dailyNetPnl：28.759039880952383
# totalCommission：217.13664999999997
# dailyCommission：2.5849601190476186
# totalSlippage：0.134
# dailySlippage：0.0015952380952380953
# totalTurnover：434273.30000000005
# dailyTurnover：5169.920238095238
# totalTradeCount：67
# dailyTradeCount：0.7976190476190477
# totalReturn：0.24157593500000463
# annualizedReturn：0.6902169571428703
# dailyReturn：0.0027427036217275713
# returnStd：0.015026430634984163
# sharpeRatio：2.8276696465234363
# ------------------------------
# 参数：["{'fastPeriod': 15, 'slowPeriod': 60, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.8219252889541417
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：51
# lossDays：31
# endBalance：1002453.21977
# maxDrawdown：-515.0634200000204
# maxDdPercent：-0.051472837168032706
# totalNetPnl：2453.219769999998
# dailyNetPnl：29.204997261904737
# totalCommission：215.79623
# dailyCommission：2.569002738095238
# totalSlippage：0.134
# dailySlippage：0.0015952380952380953
# totalTurnover：431592.45999999996
# dailyTurnover：5138.005476190476
# totalTradeCount：67
# dailyTradeCount：0.7976190476190477
# totalReturn：0.24532197700000147
# annualizedReturn：0.7009199342857184
# dailyReturn：0.0027871910556336098
# returnStd：0.01530124781605111
# sharpeRatio：2.8219252889541417
# ------------------------------
# 参数：["{'fastPeriod': 33, 'slowPeriod': 60, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.812781779604323
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：46
# lossDays：36
# endBalance：1002303.22716
# maxDrawdown：-496.93748000008054
# maxDdPercent：-0.049635912254903
# totalNetPnl：2303.227159999996
# dailyNetPnl：27.419370952380902
# totalCommission：203.21684000000002
# dailyCommission：2.4192480952380953
# totalSlippage：0.126
# dailySlippage：0.0015
# totalTurnover：406433.68000000005
# dailyTurnover：4838.496190476191
# totalTradeCount：63
# dailyTradeCount：0.75
# totalReturn：0.23032271600000875
# annualizedReturn：0.6580649028571679
# dailyReturn：0.0026090520786440203
# returnStd：0.014369853108757822
# sharpeRatio：2.812781779604323
# ------------------------------
# 参数：["{'fastPeriod': 30, 'slowPeriod': 85, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.8123279514925947
# 统计数据：
# ...
# totalCommission：165.22987
# dailyCommission：1.967022261904762
# totalSlippage：0.10200000000000001
# dailySlippage：0.0012142857142857144
# totalTurnover：330459.74
# dailyTurnover：3934.0445238095235
# totalTradeCount：51
# dailyTradeCount：0.6071428571428571
# totalReturn：0.21198181299999508
# annualizedReturn：0.6056623228571287
# dailyReturn：0.0023911898020587265
# returnStd：0.014180726783707645
# sharpeRatio：2.612288755646725
# ------------------------------
# 参数：["{'fastPeriod': 24, 'slowPeriod': 85, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.5959909108908987
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：42
# lossDays：40
# endBalance：1002161.80905
# maxDrawdown：-812.7238600000273
# maxDdPercent：-0.08119677588221651
# totalNetPnl：2161.8090500000026
# dailyNetPnl：25.735822023809554
# totalCommission：191.02295
# dailyCommission：2.274082738095238
# totalSlippage：0.118
# dailySlippage：0.0014047619047619047
# totalTurnover：382045.9
# dailyTurnover：4548.1654761904765
# totalTradeCount：59
# dailyTradeCount：0.7023809523809523
# totalReturn：0.21618090499999632
# annualizedReturn：0.617659728571418
# dailyReturn：0.002441072203620448
# returnStd：0.014567434657569442
# sharpeRatio：2.5959909108908987
# ------------------------------
# 参数：["{'fastPeriod': 27, 'slowPeriod': 65, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.5815406446226548
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：44
# lossDays：38
# endBalance：1002100.11467
# maxDrawdown：-510.90179999999236
# maxDdPercent：-0.05104719147142006
# totalNetPnl：2100.1146700000004
# dailyNetPnl：25.001365119047623
# totalCommission：203.10933
# dailyCommission：2.417968214285714
# totalSlippage：0.126
# dailySlippage：0.0015
# totalTurnover：406218.66000000003
# dailyTurnover：4835.936428571429
# totalTradeCount：63
# dailyTradeCount：0.75
# totalReturn：0.21001146699999307
# annualizedReturn：0.600032762857123
# dailyReturn：0.002367782690277614
# returnStd：0.014209162960087863
# sharpeRatio：2.5815406446226548
# ------------------------------
# 参数：["{'fastPeriod': 33, 'slowPeriod': 90, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.5561881098679415
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：44
# lossDays：38
# endBalance：1002129.35787
# maxDrawdown：-758.2946799999336
# maxDdPercent：-0.07577414211177713
# totalNetPnl：2129.357869999999
# dailyNetPnl：25.34949845238094
# totalCommission：173.56613000000002
# dailyCommission：2.0662634523809524
# totalSlippage：0.10600000000000001
# dailySlippage：0.001261904761904762
# totalTurnover：347132.26
# dailyTurnover：4132.526904761905
# totalTradeCount：53
# dailyTradeCount：0.6309523809523809
# totalReturn：0.21293578699999038
# annualizedReturn：0.6083879628571154
# dailyReturn：0.002468502410259871
# returnStd：0.014960508873508945
# sharpeRatio：2.5561881098679415
# ------------------------------
# 参数：["{'fastPeriod': 33, 'slowPeriod': 75, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.5354854971579184
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：43
# lossDays：39
# endBalance：1002028.19339
# maxDrawdown：-431.9809200000018
# maxDdPercent：-0.043162349798524645
# totalNetPnl：2028.1933899999963
# dailyNetPnl：24.14515940476186
# totalCommission：197.51461
# dailyCommission：2.3513644047619047
# totalSlippage：0.122
# dailySlippage：0.0014523809523809524
# totalTurnover：395029.22000000003
# dailyTurnover：4702.72880952381
# totalTradeCount：61
# dailyTradeCount：0.7261904761904762
# totalReturn：0.20281933899999327
# annualizedReturn：0.5794838257142665
# dailyReturn：0.002307348383080919
# returnStd：0.014098005090682523
# sharpeRatio：2.5354854971579184
# ------------------------------
# 参数：["{'fastPeriod': 30, 'slowPeriod': 65, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.498291417775392
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：44
# lossDays：38
# endBalance：1002030.4214
# maxDrawdown：-496.17700000002515
# maxDdPercent：-0.04956576094566532
# totalNetPnl：2030.4213999999952
# dailyNetPnl：24.171683333333277
# totalCommission：190.5106
# dailyCommission：2.2679833333333335
# totalSlippage：0.11800000000000001
# dailySlippage：0.0014047619047619047
# totalTurnover：381021.2
# dailyTurnover：4535.966666666667
# totalTradeCount：59
# dailyTradeCount：0.7023809523809523
# totalReturn：0.2030421399999982
# annualizedReturn：0.5801203999999949
# dailyReturn：0.002284985510041843
# returnStd：0.014169221034426095
# sharpeRatio：2.498291417775392
# ------------------------------
# 参数：["{'fastPeriod': 27, 'slowPeriod': 100, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.4872462996848825
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：43
# lossDays：39
# endBalance：1002095.17332
# maxDrawdown：-611.4175800000085
# maxDdPercent：-0.061077909214476686
# totalNetPnl：2095.173319999997
# dailyNetPnl：24.94253952380949
# totalCommission：153.86268
# dailyCommission：1.8316985714285716
# totalSlippage：0.094
# dailySlippage：0.0011190476190476191
# totalTurnover：307725.36
# dailyTurnover：3663.3971428571426
# totalTradeCount：47
# dailyTradeCount：0.5595238095238095
# totalReturn：0.20951733199998657
# annualizedReturn：0.5986209485713901
# dailyReturn：0.0023619124444389833
# returnStd：0.014711285430270706
# sharpeRatio：2.4872462996848825
# ------------------------------
# 参数：["{'fastPeriod': 24, 'slowPeriod': 90, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.471801199002425
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：42
# lossDays：40
# endBalance：1002030.25157
# maxDrawdown：-899.655049999943
# maxDdPercent：-0.08987504441068178
# totalNetPnl：2030.251570000004
# dailyNetPnl：24.169661547619096
# totalCommission：211.88843
# dailyCommission：2.5224813095238097
# totalSlippage：0.13
# dailySlippage：0.0015476190476190477
# totalTurnover：423776.86
# dailyTurnover：5044.962619047619
# totalTradeCount：65
# dailyTradeCount：0.7738095238095238
# totalReturn：0.2030251569999919
# annualizedReturn：0.580071877142834
# dailyReturn：0.0023097936354053517
# returnStd：0.014476556264656198
# sharpeRatio：2.471801199002425
# ------------------------------
# 参数：["{'fastPeriod': 27, 'slowPeriod': 95, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.4396618677965485
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：42
# lossDays：40
# endBalance：1002048.46977
# maxDrawdown：-730.2650399999693
# maxDdPercent：-0.0729605307555396
# totalNetPnl：2048.4697699999983
# dailyNetPnl：24.38654488095236
# totalCommission：153.86622999999997
# dailyCommission：1.831740833333333
# totalSlippage：0.094
# dailySlippage：0.0011190476190476191
# totalTurnover：307732.45999999996
# dailyTurnover：3663.481666666666
# totalTradeCount：47
# dailyTradeCount：0.5595238095238095
# totalReturn：0.2048469770000061
# annualizedReturn：0.5852770771428745
# dailyReturn：0.002306427934146916
# returnStd：0.014645893508589304
# sharpeRatio：2.4396618677965485
# ------------------------------
# 参数：["{'fastPeriod': 33, 'slowPeriod': 70, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.4252617520234296
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：45
# lossDays：37
# endBalance：1002009.20945
# maxDrawdown：-500.3159400000004
# maxDdPercent：-0.049982616922868074
# totalNetPnl：2009.2094499999946
# dailyNetPnl：23.919160119047554
# totalCommission：203.17455
# dailyCommission：2.418744642857143
# totalSlippage：0.126
# dailySlippage：0.0015
# totalTurnover：406349.1
# dailyTurnover：4837.489285714286
# totalTradeCount：63
# dailyTradeCount：0.75
# totalReturn：0.2009209449999938
# annualizedReturn：0.5740598428571252
# dailyReturn：0.0022597840908279375
# returnStd：0.014434905663273778
# sharpeRatio：2.4252617520234296
# ------------------------------
# 参数：["{'fastPeriod': 33, 'slowPeriod': 65, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.3597082841008934
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：45
# lossDays：37
# endBalance：1001991.94169
# maxDrawdown：-482.3353600000264
# maxDdPercent：-0.048180331775427895
# totalNetPnl：1991.9416899999935
# dailyNetPnl：23.71359154761897
# totalCommission：190.41031
# dailyCommission：2.266789404761905
# totalSlippage：0.11800000000000001
# dailySlippage：0.0014047619047619047
# totalTurnover：380820.62
# dailyTurnover：4533.5788095238095
# totalTradeCount：59
# dailyTradeCount：0.7023809523809523
# totalReturn：0.19919416900000542
# annualizedReturn：0.5691261971428726
# dailyReturn：0.002239268277119743
# returnStd：0.01470122184747905
# sharpeRatio：2.3597082841008934
# ------------------------------
# 参数：["{'fastPeriod': 33, 'slowPeriod': 100, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.303586137525792
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：43
# lossDays：39
# endBalance：1001929.37561
# maxDrawdown：-747.7734299999429
# maxDdPercent：-0.07471121620189991
# totalNetPnl：1929.375610000003
# dailyNetPnl：22.9687572619048
# totalCommission：160.99639
# dailyCommission：1.9166236904761904
# totalSlippage：0.098
# dailySlippage：0.0011666666666666668
# totalTurnover：321992.78
# dailyTurnover：3833.2473809523813
# totalTradeCount：49
# dailyTradeCount：0.5833333333333334
# totalReturn：0.19293756100000614
# annualizedReturn：0.5512501742857319
# dailyReturn：0.002189940493611092
# returnStd：0.0147276508097949
# sharpeRatio：2.303586137525792
# ------------------------------
# 参数：["{'fastPeriod': 33, 'slowPeriod': 50, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.25808393790099
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：43
# lossDays：40
# endBalance：1001909.75107
# maxDrawdown：-478.48193999996874
# maxDdPercent：-0.04779630706176801
# totalNetPnl：1909.7510700000032
# dailyNetPnl：22.735131785714323
# totalCommission：273.82493000000005
# dailyCommission：3.2598205952380956
# totalSlippage：0.17400000000000004
# dailySlippage：0.002071428571428572
# totalTurnover：547649.86
# dailyTurnover：6519.64119047619
# totalTradeCount：87
# dailyTradeCount：1.0357142857142858
# totalReturn：0.19097510699999098
# annualizedReturn：0.5456431628571171
# dailyReturn：0.002141612811687058
# returnStd：0.014692865246450554
# sharpeRatio：2.25808393790099
# ------------------------------
# 参数：["{'fastPeriod': 30, 'slowPeriod': 70, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.2430091745719922
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：44
# lossDays：38
# endBalance：1001859.8038999999
# maxDrawdown：-528.2365499999141
# maxDdPercent：-0.052778594406281396
# totalNetPnl：1859.8038999999937
# dailyNetPnl：22.140522619047545
# totalCommission：203.12009999999998
# dailyCommission：2.4180964285714284
# totalSlippage：0.126
# dailySlippage：0.0015
# totalTurnover：406240.2
# dailyTurnover：4836.192857142857
# totalTradeCount：63
# dailyTradeCount：0.75
# totalReturn：0.18598038999999567
# annualizedReturn：0.5313725428571305
# dailyReturn：0.0020822637547736533
# returnStd：0.01438170282328614
# sharpeRatio：2.2430091745719922
# ------------------------------
# 参数：["{'fastPeriod': 30, 'slowPeriod': 95, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.239560742376177
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：41
# lossDays：41
# endBalance：1001905.078
# maxDrawdown：-842.6737199999625
# maxDdPercent：-0.08419613557777539
# totalNetPnl：1905.077999999998
# dailyNetPnl：22.679499999999976
# totalCommission：174.226
# dailyCommission：2.0741190476190474
# totalSlippage：0.10600000000000001
# dailySlippage：0.001261904761904762
# totalTurnover：348452.0
# dailyTurnover：4148.238095238095
# totalTradeCount：53
# dailyTradeCount：0.6309523809523809
# totalReturn：0.190507800000006
# annualizedReturn：0.5443080000000171
# dailyReturn：0.0021450874532075964
# returnStd：0.014838424027055987
# sharpeRatio：2.239560742376177
# ------------------------------
# 参数：["{'fastPeriod': 15, 'slowPeriod': 85, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.2062233658157404
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：44
# lossDays：38
# endBalance：1001932.13287
# maxDrawdown：-951.1809099999955
# maxDdPercent：-0.09503791553566371
# totalNetPnl：1932.1328700000008
# dailyNetPnl：23.001581785714297
# totalCommission：217.28313
# dailyCommission：2.5867039285714286
# totalSlippage：0.134
# dailySlippage：0.0015952380952380953
# totalTurnover：434566.26
# dailyTurnover：5173.407857142857
# totalTradeCount：67
# dailyTradeCount：0.7976190476190477
# totalReturn：0.19321328699999363
# annualizedReturn：0.5520379628571246
# dailyReturn：0.0021682067263215222
# returnStd：0.015224983421519064
# sharpeRatio：2.2062233658157404
# ------------------------------
# 参数：["{'fastPeriod': 30, 'slowPeriod': 100, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.205449916058595
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：42
# lossDays：40
# endBalance：1001876.96086
# maxDrawdown：-774.7947200000053
# maxDdPercent：-0.07740822773216059
# totalNetPnl：1876.9608599999983
# dailyNetPnl：22.344772142857124
# totalCommission：154.03514
# dailyCommission：1.833751666666667
# totalSlippage：0.094
# dailySlippage：0.0011190476190476191
# totalTurnover：308070.28
# dailyTurnover：3667.5033333333336
# totalTradeCount：47
# dailyTradeCount：0.5595238095238095
# totalReturn：0.18769608599999987
# annualizedReturn：0.5362745314285711
# dailyReturn：0.0021026506167013776
# returnStd：0.014769831338415815
# sharpeRatio：2.205449916058595
# ------------------------------
# 参数：["{'fastPeriod': 27, 'slowPeriod': 90, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.201298277951344
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：41
# lossDays：41
# endBalance：1001776.16759
# maxDrawdown：-843.0344199999236
# maxDdPercent：-0.08422735072244988
# totalNetPnl：1776.1675900000002
# dailyNetPnl：21.144852261904767
# totalCommission：185.38841
# dailyCommission：2.207004880952381
# totalSlippage：0.114
# dailySlippage：0.0013571428571428571
# totalTurnover：370776.82
# dailyTurnover：4414.009761904762
# totalTradeCount：57
# dailyTradeCount：0.6785714285714286
# totalReturn：0.17761675899998774
# annualizedReturn：0.5074764542856793
# dailyReturn：0.0020078872962493387
# returnStd：0.014130777527655004
# sharpeRatio：2.201298277951344
# ------------------------------
# 参数：["{'fastPeriod': 33, 'slowPeriod': 95, 'symbolList': ['BTCUSDT:binance']}"]，目标：2.0100742425192877
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：41
# lossDays：41
# endBalance：1001694.70719
# maxDrawdown：-973.4196999999695
# maxDdPercent：-0.09726607378257202
# totalNetPnl：1694.7071900000005
# dailyNetPnl：20.1750855952381
# totalCommission：174.29681
# dailyCommission：2.074962023809524
# totalSlippage：0.10600000000000001
# dailySlippage：0.001261904761904762
# totalTurnover：348593.62
# dailyTurnover：4149.924047619048
# totalTradeCount：53
# dailyTradeCount：0.6309523809523809
# totalReturn：0.16947071899999777
# annualizedReturn：0.48420205428570795
# dailyReturn：0.00195204859293104
# returnStd：0.015044721297326896
# sharpeRatio：2.0100742425192877
# ------------------------------
# 参数：["{'fastPeriod': 30, 'slowPeriod': 90, 'symbolList': ['BTCUSDT:binance']}"]，目标：1.986144949028892
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：43
# lossDays：39
# endBalance：1001650.73346
# maxDrawdown：-955.9147299999604
# maxDdPercent：-0.095503349782352
# totalNetPnl：1650.7334600000004
# dailyNetPnl：19.651588809523815
# totalCommission：211.74653999999998
# dailyCommission：2.5207921428571427
# totalSlippage：0.13
# dailySlippage：0.0015476190476190477
# totalTurnover：423493.08
# dailyTurnover：5041.584285714286
# totalTradeCount：65
# dailyTradeCount：0.7738095238095238
# totalReturn：0.1650733459999998
# annualizedReturn：0.47163813142857086
# dailyReturn：0.0018428337111937798
# returnStd：0.01437410552895008
# sharpeRatio：1.986144949028892
# ------------------------------
# 参数：["{'fastPeriod': 27, 'slowPeriod': 40, 'symbolList': ['BTCUSDT:binance']}"]，目标：1.6445039844247744
# 统计数据：
# startDate：2018-09-01 00:00:00
# endDate：2018-11-23 00:00:00
# totalDays：84
# profitDays：42
# lossDays：40
# endBalance：1001428.53592
# maxDrawdown：-631.3888299999526
# maxDdPercent：-0.06307043894136566
# totalNetPnl：1428.5359200000037
# dailyNetPnl：17.006380000000043
# totalCommission：408.14007999999995
# dailyCommission：4.858810476190476
# totalSlippage：0.254
# dailySlippage：0.0030238095238095237
# totalTurnover：816280.1599999999
# dailyTurnover：9717.620952380952
# totalTradeCount：127
# dailyTradeCount：1.5119047619047619
# totalReturn：0.14285359200001402
# annualizedReturn：0.40815312000004006
# dailyReturn：0.001569692239598654
# returnStd：0.01478717463798204
# sharpeRatio：1.6445039844247744
